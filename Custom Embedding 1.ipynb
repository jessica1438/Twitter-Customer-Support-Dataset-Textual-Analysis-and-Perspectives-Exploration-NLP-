# %% [markdown]
# ## Task 3 and 4:
#
#
# Word Embedding Models: Train and create word embedding models, including Word2Vec, GloVe, and FastText, on the same dataset.
#
# Comparison of Similar Words: Compare words similar to the top 15 most frequent words identified in step 1 using the word embedding models.

# %%
import pandas as pd
import re
import string

#Preprocess the dtext data in the twitter file before implementing the embedding models
#We convert all the alphabets to lowercase as all wors will be consdiered equally and not with bias(for example if they have an upper case letter)
#Removed all the @ tags, # hashtags and urls
#removed all the special characters and Punctuations and tokenized them into words

def preprocess_tweet(tweet):

    tweet = tweet.lower()
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F700-\U0001F77F"  # alchemical symbols
                               u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                               u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                               u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                               u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                               u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                               u"\U0001F004-\U0001F0CF"  # Miscellaneous Symbols and Pictographs
                               u"\U0001F170-\U0001F251"  # Enclosed Alphanumeric Supplement
                               u"\U0001F300-\U0001F5FF"  # Miscellaneous Symbols and Pictographs
                               u"\U0001F600-\U0001F64F"  # Emoticons
                               "]+", flags=re.UNICODE)

    # Use the sub method to remove emojis
    tweet = emoji_pattern.sub(r'', tweet)
    tweet = re.sub(r'@\w+', '', tweet)
    tweet = re.sub(r'#', '', tweet)
    tweet = re.sub(r'http\S+|www\S+|https\S+', '', tweet)
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    tokens = tweet.split()
    preprocessed_tweet = ' '.join(tokens)
    return preprocessed_tweet

data = pd.read_csv('twcs.csv')

data['text'] = data['text'].apply(preprocess_tweet)

# %%
data.head()
# Out:
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  i understand i would like to assist you we wou...                 2
# 1                  and how do you propose we do that               NaN
# 2  i have sent several private messages and no on...                 1
# 3  please send us a private message so that we ca...                 3
# 4                                              i did                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# 4                      6.0

# %%
#Display the tokenized words
sentences = []
for text in data['text']:
    if isinstance(text, str):
        sentences.append(text.split())

# %%
sentences
# Out:
# [['i',
#   'understand',
#   'i',
#   'would',
#   'like',
#   'to',
#   'assist',
#   'you',
#   'we',
#   'would',
#   'need',
#   'to',
#   'get',
#   'you',
#   'into',
#   'a',
#   'private',
#   'secured',
#   'link',
#   'to',
#   'further',
#   'assist'],
#  ['and', 'how', 'do', 'you', 'propose', 'we', 'do', 'that'],
#  ['i',
#   'have',
#   'sent',
#   'several',
#   'private',
#   'messages',
#   'and',
#   'no',
#   'one',
#   'is',
#   'responding',
#   'as',
#   'usual'],
#  ['please',
#   'send',
#   'us',
#   'a',
#   'private',
#   'message',
#   'so',
#   'that',
#   'we',
#   'can',
#   'further',
#   'assist',
#   'you',
#   'just',
#   'click',
#   '‘message’',
#   'at',
#   'the',
#   'top',
#   'of',
#   'your',
#   'profile'],
#  ['i', 'did'],
#  ['can',
#   'you',
#   'please',
#   'send',
#   'us',
#   'a',
#   'private',
#   'message',
#   'so',
#   'that',
#   'i',
#   'can',
#   'gain',
#   'further',
#   'details',
#   'about',
#   'your',
#   'account'],
#  ['is', 'the', 'worst', 'customer', 'service'],
#  ['this',
#   'is',
#   'saddening',
#   'to',
#   'hear',
#   'please',
#   'shoot',
#   'us',
#   'a',
#   'dm',
#   'so',
#   'that',
#   'we',
#   'can',
#   'look',
#   'into',
#   'this',
#   'for',
#   'you',
#   'kc'],
#  ['you',
#   'gonna',
#   'magically',
#   'change',
#   'your',
#   'connectivity',
#   'for',
#   'me',
#   'and',
#   'my',
#   'whole',
#   'family'],
#  ['we',
#   'understand',
#   'your',
#   'concerns',
#   'and',
#   'wed',
#   'like',
#   'for',
#   'you',
#   'to',
#   'please',
#   'send',
#   'us',
#   'a',
#   'direct',
#   'message',
#   'so',
#   'that',
#   'we',
#   'can',
#   'further',
#   'assist',
#   'you',
#   'aa'],
#  ['since', 'i', 'signed', 'up', 'with', 'yousince', 'day', '1'],
#  ['h',
#   'there',
#   'wed',
#   'definitely',
#   'like',
#   'to',
#   'work',
#   'with',
#   'you',
#   'on',
#   'this',
#   'how',
#   'long',
#   'have',
#   'you',
#   'been',
#   'experiencing',
#   'this',
#   'issue',
#   'aa'],
#  ['y’all',
#   'lie',
#   'about',
#   'your',
#   '“great”',
#   'connection',
#   '5',
#   'bars',
#   'lte',
#   'still',
#   'won’t',
#   'load',
#   'something',
#   'smh'],
#  ['please',
#   'send',
#   'me',
#   'a',
#   'private',
#   'message',
#   'so',
#   'that',
#   'i',
#   'can',
#   'send',
#   'you',
#   'the',
#   'link',
#   'to',
#   'access',
#   'your',
#   'account',
#   'fr'],
#  ['whenever',
#   'i',
#   'contact',
#   'customer',
#   'support',
#   'they',
#   'tell',
#   'me',
#   'i',
#   'have',
#   'shortcode',
#   'enabled',
#   'on',
#   'my',
#   'account',
#   'but',
#   'i',
#   'have',
#   'never',
#   'in',
#   'the',
#   '4',
#   'years',
#   'ive',
#   'tried'],
#  ['what', 'information', 'is', 'incorrect', 'jk'],
#  ['would',
#   'you',
#   'like',
#   'me',
#   'to',
#   'email',
#   'you',
#   'a',
#   'copy',
#   'of',
#   'one',
#   'since',
#   'spectrum',
#   'is',
#   'not',
#   'updating',
#   'your',
#   'training'],
#  ['our',
#   'department',
#   'is',
#   'part',
#   'of',
#   'the',
#   'corporate',
#   'office',
#   'if',
#   'youre',
#   'particular',
#   'area',
#   'has',
#   'gone',
#   'to',
#   'this',
#   'format',
#   'we',
#   'were',
#   'unawa'],
#  ['i',
#   'received',
#   'this',
#   'from',
#   'your',
#   'corporate',
#   'office',
#   'would',
#   'you',
#   'like',
#   'a',
#   'copy'],
#  ['no', 'thank', 'you', 'jk'],
#  ['the',
#   'correct',
#   'way',
#   'to',
#   'do',
#   'it',
#   'is',
#   'via',
#   'an',
#   'ocs',
#   'account',
#   'takeover',
#   'and',
#   'email',
#   'consent',
#   'form',
#   'it',
#   'does',
#   'not',
#   'need',
#   'to',
#   'be',
#   'done',
#   'in',
#   'a',
#   'local',
#   'office'],
#  ['that',
#   'is',
#   'incorrect',
#   'information',
#   'i',
#   'have',
#   'the',
#   'form',
#   'in',
#   'front',
#   'of',
#   'me',
#   'that',
#   'is',
#   'faxed',
#   'overmaybe',
#   'you',
#   'need',
#   'to',
#   'maintain',
#   'up',
#   'to',
#   'date',
#   'information'],
#  ['the',
#   'information',
#   'pertaining',
#   'to',
#   'the',
#   'account',
#   'assumption',
#   'is',
#   'correct',
#   'this',
#   'does',
#   'need',
#   'to',
#   'be',
#   'done',
#   'at',
#   'a',
#   'local',
#   'outlet',
#   'wit'],
#  ['actually',
#   'thats',
#   'a',
#   'broken',
#   'link',
#   'you',
#   'sent',
#   'me',
#   'and',
#   'incorrect',
#   'information'],
#  ['hello',
#   'my',
#   'apologies',
#   'for',
#   'any',
#   'frustrations',
#   'or',
#   'inconvenience',
#   'i’d',
#   'be',
#   'happy',
#   'to',
#   'look',
#   'into',
#   'this',
#   'for',
#   'you',
#   'mg'],
#  ['yo',
#   'your',
#   'customer',
#   'service',
#   'reps',
#   'are',
#   'super',
#   'nice—',
#   'but',
#   'imma',
#   'start',
#   'trippin',
#   'if',
#   'y’all',
#   'don’t',
#   'get',
#   'my',
#   'service',
#   'going'],
#  ['i',
#   'apologize',
#   'for',
#   'the',
#   'inconvenience',
#   'i',
#   'will',
#   'be',
#   'glad',
#   'to',
#   'assist',
#   'you',
#   'can',
#   'you',
#   'dm',
#   'me',
#   'your',
#   'name',
#   'and',
#   'acct',
#   'or',
#   'phone',
#   'jb'],
#  ['my',
#   'picture',
#   'on',
#   'pretty',
#   'much',
#   'every',
#   'day',
#   'why',
#   'should',
#   'i',
#   'pay',
#   '171',
#   'per',
#   'month'],
#  ['help',
#   'has',
#   'arrived',
#   'we',
#   'are',
#   'sorry',
#   'to',
#   'see',
#   'that',
#   'you',
#   'are',
#   'having',
#   'trouble',
#   'how',
#   'can',
#   'we',
#   'help',
#   'hsb'],
#  ['i', 'finally', 'got', 'someone', 'that', 'helped', 'me', 'thanks'],
#  ['awesome',
#   'if',
#   'you',
#   'ever',
#   'need',
#   'us',
#   'we',
#   'are',
#   'just',
#   'a',
#   'tweet',
#   'away',
#   'hsb'],
#  ['somebody',
#   'from',
#   'please',
#   'help',
#   'meeeeee',
#   'im',
#   'having',
#   'the',
#   'worst',
#   'luck',
#   'with',
#   'your',
#   'customer',
#   'service'],
#  ['have', 'your', 'friend', 'message', 'us', 'acm'],
#  ['my',
#   'friend',
#   'is',
#   'without',
#   'internet',
#   'we',
#   'need',
#   'to',
#   'play',
#   'videogames',
#   'together',
#   'please',
#   'our',
#   'skills',
#   'diminish',
#   'every',
#   'moment',
#   'without',
#   'internetz'],
#  ['please',
#   'follow',
#   'and',
#   'dm',
#   'us',
#   'so',
#   'that',
#   'we',
#   'can',
#   'look',
#   'into',
#   'this',
#   'order',
#   'hsb'],
#  ['what',
#   'else',
#   'can',
#   'i',
#   'provide',
#   'they',
#   'refuse',
#   'to',
#   'help',
#   'me',
#   'because',
#   'they',
#   'cannot',
#   'validate',
#   'the',
#   'account'],
#  ['we',
#   'would',
#   'not',
#   'be',
#   'able',
#   'to',
#   'verify',
#   'anything',
#   'without',
#   'authenticating',
#   'your',
#   'account',
#   'jay'],
#  ['how',
#   'i',
#   'have',
#   'my',
#   'phone',
#   'number',
#   'and',
#   'email',
#   'thats',
#   'it',
#   'how',
#   'did',
#   'i',
#   'get',
#   'equipment',
#   'and',
#   'service',
#   'im',
#   'literally',
#   'trying',
#   'to',
#   'pay',
#   'and',
#   'nobody',
#   'can',
#   'find',
#   'me'],
#  ['we',
#   'can',
#   'use',
#   'the',
#   'order',
#   'number',
#   'to',
#   'locate',
#   'the',
#   'account',
#   'but',
#   'will',
#   'need',
#   'to',
#   'do',
#   'so',
#   'in',
#   'our',
#   'secure',
#   'one',
#   'on',
#   'one',
#   'chat',
#   'please',
#   'follow',
#   'and',
#   'dm',
#   'us',
#   'hsb'],
#  ['md', 'and', 'this', 'was', 'sent', 'to', 'the', 'wrong', 'address'],
#  ['hello',
#   'duke',
#   'do',
#   'you',
#   'have',
#   'a',
#   'copy',
#   'of',
#   'your',
#   'bill',
#   'what',
#   'state',
#   'are',
#   'your',
#   'services',
#   'located',
#   'in',
#   'nhp'],
#  ['nobody',
#   'can',
#   'find',
#   'my',
#   'account',
#   'or',
#   'number',
#   'i',
#   'walked',
#   'out',
#   'of',
#   'a',
#   'store',
#   'with',
#   'this',
#   'ive',
#   'explained',
#   'that',
#   'they',
#   'can',
#   'find',
#   'my',
#   'acct',
#   'via',
#   'my',
#   'devices',
#   'serial'],
#  ['are',
#   'you',
#   'referring',
#   'to',
#   'wireless',
#   'or',
#   'residential',
#   'service',
#   'jay'],
#  ['tried',
#   'to',
#   'pay',
#   'a',
#   'bill',
#   'for',
#   '60',
#   'days',
#   'no',
#   'service',
#   'rude',
#   'cs',
#   'and',
#   'several',
#   'transfers',
#   'look',
#   'up',
#   'my',
#   'equipment',
#   'and',
#   'give',
#   'me',
#   'an',
#   'acct'],
#  ['is', 'the', 'light', 'on', 'top', 'red', 'jay'],
#  ['don’t',
#   'know',
#   'router',
#   'is',
#   'downstairs',
#   'but',
#   'it’s',
#   'just',
#   'the',
#   'wifi',
#   'nothing',
#   'connected',
#   'to',
#   'ethernet'],
#  ['did',
#   'the',
#   'lights',
#   'change',
#   'on',
#   'the',
#   'router',
#   'when',
#   'this',
#   'happened',
#   'jay'],
#  ['just',
#   'randomly',
#   'boots',
#   'me',
#   'offline',
#   'there',
#   'it',
#   'goes',
#   'again'],
#  ['do',
#   'you',
#   'have',
#   'our',
#   'fios',
#   'service',
#   'when',
#   'services',
#   'go',
#   'out',
#   'does',
#   'the',
#   'internet',
#   'light',
#   'on',
#   'the',
#   'router',
#   'change',
#   'color',
#   'bcw'],
#  ['yep'],
#  ['are', 'all', 'your', 'services', 'cutting', 'out', 'acm'],
#  ['cuts', 'out', 'every', '20', 'minutes', 'this', 'is', 'ridiculous'],
#  ['what',
#   'did',
#   'we',
#   'do',
#   'to',
#   'make',
#   'you',
#   'feel',
#   'this',
#   'way',
#   'and',
#   'how',
#   'can',
#   'we',
#   'fix',
#   'things',
#   'between',
#   'us',
#   'kmg'],
#  ['is', 'the', 'worst', 'isp', 'i’ve', 'ever', 'had'],
#  ['in',
#   'what',
#   'area',
#   'are',
#   'you',
#   'located',
#   'all',
#   'of',
#   'your',
#   'services',
#   'are',
#   'down',
#   'at',
#   'this',
#   'time',
#   'hsb'],
#  ['gtall',
#   'of',
#   'verizon',
#   'is',
#   'downlt',
#   'when',
#   'can',
#   'we',
#   'expect',
#   'a',
#   'fix'],
#  ['which', 'app', 'are', 'you', 'referring', 'too', 'acm'],
#  ['fix', 'your', 'app', 'it', 'wont', 'even', 'open'],
#  ['i', 'still', 'think', 'you', 'look', 'great', 'becky'],
#  ['becky', 'is', 'very', 'nice'],
#  ['i', 'dont', 'fit', 'in', 'my', 'veggie', 'burrito', 'costume', 'halloween'],
#  ['im',
#   'so',
#   'sorry',
#   'about',
#   'that',
#   'please',
#   'tell',
#   'us',
#   'more',
#   'so',
#   'we',
#   'can',
#   'help',
#   'becky'],
#  ['messed',
#   'up',
#   'today',
#   'and',
#   'didn’t',
#   'give',
#   'me',
#   'my',
#   '3',
#   'burrito',
#   'although',
#   'i',
#   'was',
#   'dressed',
#   'up'],
#  ['hopefully', 'well', 'get', 'there', 'at', 'some', 'point', 'becky'],
#  ['hey',
#   'wanna',
#   'come',
#   'to',
#   'mammoth',
#   'ill',
#   'at',
#   'least',
#   'eat',
#   'there',
#   'once',
#   'a',
#   'week',
#   'i',
#   'promise'],
#  ['guac',
#   'on',
#   'im',
#   'happy',
#   'it',
#   'was',
#   'such',
#   'a',
#   'great',
#   'experience',
#   'becky'],
#  ['i',
#   'had',
#   'excellent',
#   'service',
#   'tonight',
#   'too',
#   'plenty',
#   'of',
#   'people',
#   'on',
#   'the',
#   'line',
#   'went',
#   'very',
#   'fast',
#   'everyone',
#   'was',
#   'kind'],
#  ['its', 'because', 'youre', 'smart', 'tara'],
#  ['when', 'youre', 'the', 'only', 'one', 'in', 'costume', 'boorito'],
#  ['thats',
#   'incredibly',
#   'concerning',
#   'please',
#   'tell',
#   'us',
#   'more',
#   'here',
#   'becky'],
#  ['no',
#   'diet',
#   'coke',
#   'and',
#   'a',
#   'literal',
#   'bone',
#   'this',
#   'boorito',
#   'was',
#   'extra',
#   'spooky'],
#  ['nope', 'still', 'just', 'the', '3', 'becky'],
#  ['if',
#   'you',
#   'get',
#   'queso',
#   'or',
#   'quac',
#   'on',
#   'youre',
#   'bowl',
#   'its',
#   'extra'],
#  ['just',
#   'stop',
#   'by',
#   'in',
#   'costume',
#   '1031',
#   '3pmclose',
#   'official',
#   'rules'],
#  ['i',
#   'mean',
#   'boorito',
#   'is',
#   'basically',
#   'the',
#   'adult',
#   'version',
#   'of',
#   'halloween',
#   'becky'],
#  ['happy',
#   'halloween',
#   'since',
#   'im',
#   'too',
#   'old',
#   'to',
#   'trick',
#   'or',
#   'treat',
#   'i',
#   'now',
#   'look',
#   'forward',
#   'to',
#   '3',
#   'booritos',
#   'at',
#   'i',
#   'got',
#   'mine',
#   'earlier',
#   'did',
#   'you'],
#  ['im',
#   'so',
#   'glad',
#   'we',
#   'could',
#   'help',
#   'who',
#   'did',
#   'you',
#   'work',
#   'with',
#   'id',
#   'like',
#   'to',
#   'share',
#   'the',
#   'praise',
#   'becky'],
#  ['thank',
#   'you',
#   'for',
#   'resolving',
#   'my',
#   'issue',
#   'so',
#   'quickly',
#   'y’all',
#   'are',
#   'the',
#   'best',
#   '☺️',
#   'fanforlife'],
#  ['so',
#   'frustrated',
#   'with',
#   'ordered',
#   'dinner',
#   'on',
#   'saturday',
#   'using',
#   'their',
#   'app',
#   'order',
#   'was',
#   'wrong',
#   'and',
#   'they',
#   'charged',
#   'my',
#   'credit',
#   'card',
#   'twice'],
#  ['all', 'of', 'our', 'us', 'locations', 'are', 'participating', 'becky'],
#  ['btw',
#   'giving',
#   'out',
#   '3',
#   'burritos',
#   'if',
#   'you',
#   'dress',
#   'up',
#   'for',
#   'halloween',
#   'call',
#   'your',
#   'chipotle',
#   'to',
#   'make',
#   'sure',
#   'they’re',
#   'doing',
#   'it',
#   'select',
#   'ones'],
#  ['my',
#   'apologies',
#   'for',
#   'that',
#   'just',
#   'sent',
#   'you',
#   'a',
#   'dm',
#   'to',
#   'help',
#   'becky'],
#  ['tried', 'didnt', 'work', 'how', 'rude'],
#  ['give', 'it', 'a', 'try', 'tara'],
#  ['can',
#   'i',
#   'dress',
#   'up',
#   'as',
#   'myself',
#   'and',
#   'still',
#   'qualify',
#   'for',
#   'a',
#   'boorito'],
#  ['thats',
#   'the',
#   'best',
#   'kind',
#   'of',
#   'trickortreating',
#   'all',
#   'treats',
#   'my',
#   'friend',
#   'becky'],
#  ['every',
#   'year',
#   'my',
#   'trickortreating',
#   'routine',
#   'is',
#   'walking',
#   'to',
#   'chipotle',
#   'spending',
#   '3',
#   'dollars',
#   'and',
#   'walking',
#   'back',
#   'home'],
#  ['thats',
#   'incredibly',
#   'concerning',
#   'please',
#   'provide',
#   'more',
#   'details',
#   'so',
#   'we',
#   'can',
#   'investigate',
#   'becky'],
#  ['this', 'is', 'nasty', 'a', 'used', 'napkin', 'in', 'someones', 'food'],
#  ['bummer',
#   'im',
#   'so',
#   'sorry',
#   'how',
#   'far',
#   'away',
#   'is',
#   'the',
#   'closest',
#   'location',
#   'becky'],
#  ['3', 'burritos', 'and', 'i’m', 'nowhere', 'near', 'a', '\u200d♂️'],
#  ['noted', 'becky'],
#  ['also', 'i', 'got', 'the', 'onesie', 'at', 'target', 'so', 'cozy'],
#  ['thanks',
#   'becky',
#   'just',
#   'feeling',
#   'sorry',
#   'for',
#   'myself',
#   'because',
#   'my',
#   'fiancé',
#   'is',
#   'driving',
#   'from',
#   'dc',
#   'to',
#   'mississippi',
#   'tonight'],
#  ['you',
#   'wont',
#   'be',
#   'alone',
#   '–',
#   'well',
#   'be',
#   'there',
#   'with',
#   'you',
#   'also',
#   'i',
#   'want',
#   'that',
#   'llama',
#   'onesie',
#   'becky'],
#  ['considering',
#   'walking',
#   'to',
#   'in',
#   'my',
#   'llama',
#   'onesie',
#   'alone',
#   'happy',
#   'halloween'],
#  ['i', 'love', 'it', 'thanks', 'so', 'much', 'for', 'stopping', 'by', 'becky'],
#  ['name', 'a', 'better', 'halloween', 'duo', 'speedwaybrick', 'uttranscript'],
#  ['there',
#   'is',
#   'no',
#   'info',
#   'to',
#   'share',
#   'at',
#   'the',
#   'moment',
#   'feel',
#   'free',
#   'to',
#   'keep',
#   'an',
#   'eye',
#   'on',
#   'the',
#   'ps',
#   'blog',
#   'for',
#   'news',
#   'and',
#   'updates'],
#  ['can', 'i', 'get', 'help', 'already'],
#  ['so', 'whats', 'the', 'november', 'ps', 'plus', 'free', 'game'],
#  ['glad',
#   'to',
#   'know',
#   'that',
#   'is',
#   'downloading',
#   'please',
#   'feel',
#   'free',
#   'to',
#   'contact',
#   'us',
#   'if',
#   'you',
#   'have',
#   'further',
#   'concerns'],
#  ['it',
#   'was',
#   'when',
#   'i',
#   'would',
#   'go',
#   'to',
#   'download',
#   'it',
#   'i',
#   'just',
#   'waited',
#   'a',
#   'few',
#   'hours',
#   'till',
#   'after',
#   'i',
#   'bought',
#   'it',
#   'and',
#   'it',
#   'downloaded',
#   'now'],
#  ['sorry',
#   'for',
#   'the',
#   'inconvenience',
#   'do',
#   'you',
#   'see',
#   'the',
#   'data',
#   'corrupted',
#   'message',
#   'when',
#   'you',
#   'try',
#   'to',
#   'open',
#   'the',
#   'game',
#   'or',
#   'download',
#   'it'],
#  ['i',
#   'bought',
#   'lego',
#   'star',
#   'wars',
#   'in',
#   'the',
#   'playstation',
#   'store',
#   'but',
#   'it',
#   'wont',
#   'let',
#   'me',
#   'download',
#   'it',
#   'because',
#   'the',
#   'data',
#   'is',
#   'corrupted'],
#  ['glad',
#   'to',
#   'help',
#   'please',
#   'share',
#   'the',
#   'details',
#   'of',
#   'this',
#   'issue',
#   'in',
#   'our',
#   'community',
#   'forum',
#   'for',
#   'further',
#   'investigation'],
#  ['can',
#   'i',
#   'block',
#   'a',
#   'community',
#   'from',
#   'sending',
#   'me',
#   'invites',
#   'to',
#   'something',
#   'i',
#   'dont',
#   'want',
#   'to',
#   'join'],
#  ['glad',
#   'you',
#   'had',
#   'fun',
#   'sarah',
#   'we',
#   'heard',
#   'count',
#   'collin',
#   'can',
#   'really',
#   'suck',
#   'the',
#   'life',
#   'out',
#   'of',
#   'the',
#   'party',
#   'p'],
#  ['we', 'had', 'to', 'have', 'a', 'count', 'colin', 'xx'],
#  ['weve',
#   'let',
#   'our',
#   'team',
#   'know',
#   'we',
#   'can',
#   'do',
#   'better',
#   'joel',
#   'thanks',
#   'for',
#   'sharing'],
#  ['‘ere',
#   'never',
#   'mind',
#   'avocado',
#   'how’s',
#   'about',
#   '‘ave',
#   'a',
#   'word',
#   'is',
#   'it',
#   'really',
#   'necessary',
#   'the',
#   'pair',
#   'of',
#   '‘em',
#   'were',
#   'suffocating'],
#  ['were',
#   'only',
#   'obligated',
#   'to',
#   'provide',
#   'bags',
#   'for',
#   'unpackaged',
#   'meat',
#   'as',
#   'ours',
#   'is',
#   'prepackaged',
#   'a',
#   'charge',
#   'will',
#   'be',
#   'applied'],
#  ['raw',
#   'meat',
#   'it’s',
#   'does',
#   'not',
#   'say',
#   'unwrapped',
#   'raw',
#   'meat',
#   'sainsbury’s',
#   'don’t',
#   'charge',
#   'nor',
#   'do',
#   'waitrose',
#   'so',
#   'y',
#   'do',
#   'you'],
#  ['as',
#   'our',
#   'packaging',
#   'is',
#   'sufficient',
#   'any',
#   'extra',
#   'wrappings',
#   'or',
#   'bags',
#   'does',
#   'require',
#   'an',
#   'extra',
#   '5p',
#   'charge',
#   'as',
#   'per',
#   'legislation',
#   'thanks'],
#  ['i',
#   'check',
#   'with',
#   'the',
#   'gov',
#   'office',
#   'and',
#   'legal',
#   'they',
#   'stated',
#   'you',
#   'are',
#   'not',
#   'right',
#   'but',
#   'it’s',
#   'funny',
#   'how',
#   'the',
#   'other',
#   'stores',
#   'don’t',
#   'but',
#   'you',
#   'do',
#   'no',
#   'wonder',
#   'lidl',
#   'and',
#   'the',
#   'rest',
#   'are',
#   'beating',
#   'you'],
#  ['ou',
#   'must',
#   'charge',
#   'at',
#   'least',
#   '5p',
#   'a',
#   'bag',
#   'including',
#   'vat',
#   'for',
#   'carrier',
#   'bags',
#   'that',
#   'are',
#   'all',
#   'of',
#   'the',
#   'following',
#   'unused',
#   'it’s',
#   'new',
#   'and',
#   'hasn’t',
#   'already',
#   'been',
#   'used',
#   'for',
#   'sold',
#   'goods',
#   'to',
#   'be',
#   'taken',
#   'away',
#   'or',
#   'delivered',
#   'plastic',
#   'and',
#   '70',
#   'microns',
#   'thick',
#   'or',
#   'less',
#   'it',
#   'has',
#   'handles',
#   'an',
#   'opening',
#   'and',
#   'isn’t',
#   'sealed'],
#  ['aren’t',
#   'require',
#   'charge',
#   '4',
#   'a',
#   'bag',
#   'paper',
#   'bags',
#   'shops',
#   'in',
#   'airports',
#   'or',
#   'on',
#   'board',
#   'trains',
#   'aeroplanes',
#   'or',
#   'ships',
#   'bags',
#   'which',
#   'only',
#   'contain',
#   'certain',
#   'items',
#   'such',
#   'as',
#   'unwrapped',
#   'food',
#   'raw',
#   'meat',
#   'and',
#   'fish',
#   'where',
#   'there',
#   'is',
#   'a',
#   'food',
#   'safety',
#   'risk',
#   'prescription',
#   'medicines',
#   'uncovered',
#   'blades',
#   'seeds',
#   'bulbs',
#   'amp',
#   's'],
#  ['y',
#   'do',
#   'they',
#   'charge',
#   'you',
#   'for',
#   'a',
#   'meat',
#   'bag',
#   'at',
#   'colliers',
#   'woods',
#   'branch',
#   'if',
#   'you',
#   'buy',
#   'meat',
#   'you',
#   'r',
#   'required',
#   'to',
#   'supply',
#   'customers',
#   'a',
#   'free',
#   'bag',
#   'poor',
#   'service'],
#  ['love',
#   'the',
#   'aesthetic',
#   'of',
#   'your',
#   'colin',
#   'the',
#   'creeperpillar',
#   'and',
#   'someday'],
#  ['excellent', 'halloweening', 'countcolin', 'halloween', 'food'],
#  ['hello',
#   'josh',
#   'to',
#   'get',
#   'better',
#   'assistance',
#   'and',
#   'support',
#   'we',
#   'suggest',
#   'that',
#   'you',
#   'post',
#   'a',
#   'tweet',
#   'or',
#   'dm',
#   'our',
#   'friends',
#   'from'],
#  ['brilliant', 'thank', 'you'],
#  ['hi',
#   'having',
#   'trouble',
#   'making',
#   'purchases',
#   'on',
#   'xbox',
#   'one',
#   'store',
#   'for',
#   'fifa',
#   'points',
#   'can',
#   'you',
#   'help'],
#  ['help',
#   'is',
#   'here',
#   'to',
#   'assist',
#   'you',
#   'in',
#   'recovering',
#   'your',
#   'account',
#   'we',
#   'recommend',
#   'that',
#   'you',
#   'contact',
#   'our',
#   'answer',
#   'desk',
#   'team'],
#  ['i',
#   'need',
#   'assistance',
#   'recovering',
#   '2',
#   'hotmail',
#   'accounts',
#   'i',
#   'have',
#   'filled',
#   'the',
#   'recovery',
#   'forms',
#   'but',
#   'am',
#   'told',
#   'am',
#   'not',
#   'providing',
#   'enough',
#   'info'],
#  ['it',
#   'appears',
#   'this',
#   'has',
#   'been',
#   'removed',
#   'thanks',
#   'for',
#   'letting',
#   'me',
#   'know',
#   'mb'],
#  ['umm', 'someone', 'is', 'streaming', 'wwii', 'with', '500', 'viewers'],
#  ['no',
#   'problem',
#   'let',
#   'us',
#   'know',
#   'if',
#   'you',
#   'come',
#   'across',
#   'any',
#   'other',
#   'issues',
#   'or',
#   'questions',
#   'in',
#   'the',
#   'future',
#   'we',
#   'are',
#   'happy',
#   'to',
#   'help',
#   'rk'],
#  ['im',
#   'trying',
#   'to',
#   'buy',
#   'the',
#   'digital',
#   'deluxe',
#   'edition',
#   'on',
#   'the',
#   'ps',
#   'store',
#   'but',
#   'i',
#   'keep',
#   'receiving',
#   'an',
#   'error',
#   'message'],
#  ['hello',
#   'there',
#   'sorry',
#   'for',
#   'the',
#   'late',
#   'response',
#   'i',
#   'am',
#   'just',
#   'checking',
#   'if',
#   'you',
#   'still',
#   'in',
#   'need',
#   'assistance',
#   'please',
#   'let',
#   'me',
#   'know',
#   'rn'],
#  ['thanks'],
#  ['yes',
#   'you',
#   'can',
#   'pre',
#   'order',
#   'the',
#   'game',
#   'on',
#   'the',
#   'console',
#   'store',
#   'for',
#   'more',
#   'information',
#   'please',
#   'contact',
#   'your',
#   'console',
#   'store',
#   'rk'],
#  ['can',
#   'you',
#   'still',
#   'pre',
#   'oder',
#   'ww2',
#   'on',
#   'the',
#   'playstation',
#   'store'],
#  ['good',
#   'afternoon',
#   'william',
#   'unfortunately',
#   'this',
#   'app',
#   'is',
#   'no',
#   'longer',
#   'supported',
#   'sincerest',
#   'apologies',
#   'jp'],
#  ['are',
#   'yous',
#   'going',
#   'to',
#   'update',
#   'cod',
#   'zombies',
#   'on',
#   'ios',
#   'for',
#   'ios',
#   '11'],
#  ['good',
#   'afternoon',
#   'jayden',
#   'sadly',
#   'we',
#   'dont',
#   'have',
#   'information',
#   'on',
#   'that',
#   'sincerest',
#   'apologies',
#   'jp'],
#  ['why',
#   'was',
#   'there',
#   'a',
#   'half',
#   'gig',
#   'update',
#   'for',
#   'world',
#   'at',
#   'war'],
#  ['this',
#   'is',
#   'awesome',
#   'thank',
#   'you',
#   'so',
#   'much',
#   'for',
#   'the',
#   'support',
#   'love',
#   'the',
#   'costumes',
#   'tv'],
#  ['tried', 'that', 'there', 'was', 'people', 'so', 'i', 'came', 'back'],
#  ['hey',
#   'there',
#   'you',
#   'can',
#   'check',
#   'out',
#   'this',
#   'link',
#   'for',
#   'more',
#   'information',
#   'in',
#   'regards',
#   'to',
#   'this',
#   'ko'],
#  ['so',
#   'when',
#   'i',
#   'go',
#   'get',
#   'the',
#   'game',
#   'on',
#   'friday',
#   'my',
#   '2xp',
#   'code',
#   'will',
#   'be',
#   'on',
#   'the',
#   'receipt'],
#  ['did',
#   'gamestop',
#   'give',
#   'you',
#   'a',
#   'code',
#   'with',
#   'your',
#   'pre',
#   'order',
#   'down',
#   'payment',
#   'that',
#   'you',
#   'needed',
#   'to',
#   'redeem',
#   'ko'],
#  ['yes', 'the', 'beta', 'code'],
#  ['have',
#   'you',
#   'redeemed',
#   'that',
#   'on',
#   'your',
#   'account',
#   'even',
#   'tho',
#   'it',
#   'says',
#   'beta',
#   'code',
#   'your',
#   'pre',
#   'order',
#   'bonus',
#   'are',
#   'linked',
#   'ko'],
#  ['yes', 'i', 'have', 'so', 'my', 'code', 'is', 'on', 'their'],
#  ['i', 'pre', 'ordered', 'my', 'game', 'at', 'game', 'stop'],
#  ['hello',
#   'there',
#   'i',
#   'apologize',
#   'for',
#   'the',
#   'delay',
#   'can',
#   'you',
#   'clarify',
#   'where',
#   'you',
#   'preordered',
#   'the',
#   'game',
#   'please',
#   'be',
#   'sure',
#   'you',
#   'keep',
#   'us',
#   'updated',
#   'rn'],
#  ['for', 'double', 'xp'],
#  ['i',
#   'pre',
#   'ordered',
#   'wwii',
#   'but',
#   'how',
#   'do',
#   'i',
#   'get',
#   'the',
#   'code'],
#  ['can',
#   'you',
#   'please',
#   'give',
#   'me',
#   'your',
#   'gamertag',
#   'platform',
#   'youre',
#   'playing',
#   'on',
#   'so',
#   'i',
#   'can',
#   'pull',
#   'up',
#   'your',
#   'account',
#   'information',
#   'cb'],
#  ['sethtubbs', 'and', 'i', 'am', 'on', 'ps4'],
#  ['i',
#   'got',
#   'all',
#   'of',
#   'my',
#   'stats',
#   'reset',
#   'on',
#   'mwr',
#   'and',
#   'i',
#   'dont',
#   'know',
#   'why',
#   'please',
#   'help'],
#  ['unfortunately',
#   'we',
#   'dont',
#   'have',
#   'any',
#   'information',
#   'on',
#   'this',
#   'please',
#   'stay',
#   'tuned',
#   'for',
#   'more',
#   'updates',
#   'jw'],
#  ['will',
#   'non',
#   'season',
#   'pass',
#   'holders',
#   'get',
#   'the',
#   'bobus',
#   'man',
#   'carentan',
#   'at',
#   'any',
#   'point',
#   'or',
#   'not',
#   'at',
#   'all'],
#  ['sorry',
#   'that',
#   'this',
#   'isnt',
#   'more',
#   'simple',
#   'let',
#   'us',
#   'know',
#   'if',
#   'the',
#   'steps',
#   'in',
#   'the',
#   'video',
#   'work',
#   'out',
#   'or',
#   'if',
#   'you',
#   'need',
#   'further',
#   'help',
#   'madison'],
#  ['didnt',
#   'work',
#   'tried',
#   'it',
#   'on',
#   'another',
#   'computer',
#   'fresh',
#   'install',
#   'same',
#   'thing'],
#  ['would',
#   'you',
#   'please',
#   'dm',
#   'the',
#   'adobe',
#   'product',
#   'amp',
#   'your',
#   'purchase',
#   'details',
#   'that',
#   'you',
#   'have',
#   'so',
#   'that',
#   'we',
#   'can',
#   'ask',
#   'our',
#   'experts',
#   'to',
#   'follow',
#   'up',
#   'raj'],
#  ['sure', 'thing'],
#  ['the', 'ctrlaltshift', 'on', 'load', 'method', 'didnt', 'work', '22'],
#  ['hi',
#   'jason',
#   'could',
#   'you',
#   'please',
#   'try',
#   'resetting',
#   'the',
#   'preferences',
#   'of',
#   'photoshop',
#   'amp',
#   'let',
#   'us',
#   'know',
#   'if',
#   'it',
#   'helps',
#   'with',
#   'the',
#   'issue',
#   'sc'],
#  ['pretty',
#   'much',
#   'explained',
#   'my',
#   'issue',
#   'in',
#   'the',
#   'quoted',
#   'tweet',
#   'dragging',
#   'an',
#   'image',
#   'onto',
#   'a',
#   'canvas',
#   'no',
#   'longer',
#   'center',
#   'snaps',
#   'it'],
#  ['hi',
#   'jason',
#   'please',
#   'let',
#   'us',
#   'know',
#   'if',
#   'there',
#   'is',
#   'anything',
#   'we',
#   'can',
#   'do',
#   'to',
#   'help',
#   'thanks',
#   'aj'],
#  ['any', 'help', 'here'],
#  ['hi',
#   'jeffrey',
#   'were',
#   'you',
#   'able',
#   'to',
#   'update',
#   'to',
#   'lightroom',
#   'classic',
#   'cc',
#   'tanuj'],
#  ['nope', 'still', 'down'],
#  ['have',
#   'you',
#   'tried',
#   'signing',
#   'outback',
#   'in',
#   'or',
#   'reinstalling',
#   'the',
#   'cc',
#   'desktop',
#   'app',
#   'let',
#   'us',
#   'know',
#   'madison'],
#  ['yes',
#   'ive',
#   'done',
#   'that',
#   'multiple',
#   'times',
#   'its',
#   'happened',
#   'on',
#   'previous',
#   'versions',
#   'as',
#   'well'],
#  ['thanks',
#   'for',
#   'confirming',
#   'were',
#   'looping',
#   'in',
#   'an',
#   'expert',
#   'who',
#   'can',
#   'help',
#   'you',
#   'out',
#   'here',
#   'they',
#   'will',
#   'reply',
#   'as',
#   'soon',
#   'as',
#   'theyre',
#   'available',
#   'madison'],
#  ['ok'],
#  ['sowhen', 'are', 'they', 'available'],
#  ['sorry',
#   'for',
#   'this',
#   'let',
#   'me',
#   'request',
#   'the',
#   'expert',
#   'to',
#   'look',
#   'into',
#   'this',
#   'asap',
#   'as',
#   'he',
#   'is',
#   'in',
#   'office',
#   'raj'],
#  ['ok',
#   'its',
#   'been',
#   'very',
#   'frustrating',
#   'i',
#   'have',
#   'multiple',
#   'jobs',
#   'that',
#   'i',
#   'need',
#   'finished',
#   'and',
#   'your',
#   'application',
#   'isnt',
#   'helping'],
#  ['hi',
#   'jeffrey',
#   'we',
#   'wanted',
#   'to',
#   'check',
#   'if',
#   'you',
#   'had',
#   'managed',
#   'to',
#   'install',
#   'lightroom',
#   'classic',
#   'cc',
#   'please',
#   'let',
#   'us',
#   'know',
#   'if',
#   'you',
#   'need',
#   'further',
#   'assistance',
#   'nr'],
#  ['no',
#   'its',
#   'still',
#   'broken',
#   'i',
#   'deleted',
#   'it',
#   'and',
#   'will',
#   'probably',
#   'be',
#   'getting',
#   'rid',
#   'of',
#   'my',
#   'membership',
#   'and',
#   'return',
#   'when',
#   'its',
#   'working',
#   'properly',
#   'thanks'],
#  ['jeffrey',
#   'did',
#   'you',
#   'use',
#   'the',
#   'process',
#   'listed',
#   'in',
#   'to',
#   'delete',
#   'lightroom',
#   'classic',
#   'cc',
#   'jeff'],
#  ['ill',
#   'just',
#   'wait',
#   'for',
#   'the',
#   'next',
#   'big',
#   'update',
#   'ive',
#   'wasted',
#   'my',
#   'time',
#   'and',
#   'patience',
#   'with',
#   'adobe',
#   'products'],
#  ['jeffrey',
#   'i',
#   'am',
#   'sorry',
#   'to',
#   'hear',
#   'that',
#   'if',
#   'you',
#   'face',
#   'future',
#   'errors',
#   'please',
#   'review',
#   'the',
#   'installation',
#   'logs',
#   'jeff'],
#  ['yea',
#   'ive',
#   'done',
#   'everything',
#   'you',
#   'guys',
#   'told',
#   'me',
#   'to',
#   'do',
#   'i',
#   'know',
#   'its',
#   'not',
#   'my',
#   'mac',
#   'either',
#   'as',
#   'i',
#   'have',
#   'the',
#   'retina',
#   'imac',
#   'which',
#   'is',
#   'fairly',
#   'new'],
#  ['hi',
#   'there',
#   'i',
#   'am',
#   'looping',
#   'our',
#   'expert',
#   'team',
#   'to',
#   'help',
#   'answer',
#   'your',
#   'question',
#   'thanks',
#   'mc'],
#  ['you',
#   'guys',
#   'have',
#   'been',
#   'saying',
#   'that',
#   'for',
#   'weeks',
#   'now',
#   'your',
#   'product',
#   'went',
#   'from',
#   'being',
#   'great',
#   'to',
#   'now',
#   'unable',
#   'to',
#   'work',
#   'and',
#   'terrible',
#   'very',
#   'disappointed'],
#  ['whats',
#   'going',
#   'on',
#   'with',
#   'your',
#   'app',
#   'its',
#   'totally',
#   'stuck',
#   'here',
#   'for',
#   '1',
#   'hour',
#   'and',
#   'prior',
#   'to',
#   'updating',
#   'froze',
#   'and',
#   'didnt',
#   'work',
#   'since',
#   'updating'],
#  ['こんにちは、アマゾン公式です。fire',
#   'tv',
#   'stickが見れないというのは、どのような状況でしょうか。一般的なトラブルシューティングを記載したヘルプがございますので、ご参照ください。',
#   'et'],
#  ['ありがとうございます。', '今、電話で主人が対応していただいてます。'],
#  ['電話で対応してもらいましたが改良されませんでした。', '保証期間も過ぎてるので買い直しになるんでしょうね。'],
#  ['カスタマーサービスにてお問い合わせ済みとのことで、お手数をおかけいたしました。リプライいただきありがとうございました。et'],
#  ['こちらこそありがとうございました。'],
#  ['恐れ入ります。至らない点も多々あるかとは存じますが、今後ともどうぞよろしくお願いします。et'],
#  ['amazonのfiretvstickが見れない'],
#  ['hi',
#   'you',
#   'can',
#   'change',
#   'your',
#   'microsoft',
#   'account',
#   'email',
#   'through',
#   'the',
#   'steps',
#   'here',
#   'if',
#   'the',
#   'email',
#   'your',
#   'son',
#   'wants',
#   'to',
#   'change',
#   'to',
#   'is',
#   'already',
#   'associated',
#   'with',
#   'a',
#   'microsoft',
#   'account',
#   'youll',
#   'need',
#   'to',
#   'follow',
#   'those',
#   'steps',
#   'to',
#   'switch',
#   'the',
#   'email',
#   'address',
#   'on',
#   'that',
#   'account',
#   'too',
#   'zm'],
#  ['can',
#   'i',
#   'change',
#   'me',
#   'sons',
#   'xbox',
#   'live',
#   'account',
#   'to',
#   'his',
#   'hotmail',
#   'account',
#   'currently',
#   'linked',
#   'to',
#   'my',
#   'hotmail',
#   'account'],
#  ['hi',
#   'there',
#   'lightroom',
#   '701',
#   'update',
#   'was',
#   'launched',
#   'recently',
#   'please',
#   'update',
#   'the',
#   'app',
#   'to',
#   'the',
#   'latest',
#   'version',
#   'ts'],
#  ['did',
#   'u',
#   'release',
#   'an',
#   'update',
#   'today',
#   'for',
#   'lightroom',
#   'classic',
#   'cc'],
#  ['hi',
#   'there',
#   'please',
#   'dm',
#   'us',
#   'you',
#   'adobe',
#   'id',
#   'so',
#   'that',
#   'we',
#   'may',
#   'have',
#   'a',
#   'quick',
#   'look',
#   'at',
#   'your',
#   'account',
#   'details',
#   'tanuj'],
#  ['please',
#   'tell',
#   'me',
#   'why',
#   'my',
#   'has',
#   'expired',
#   'but',
#   'i’m',
#   'still',
#   'being',
#   'charged'],
#  ['hi',
#   'there',
#   'you',
#   'may',
#   'suggest',
#   'it',
#   'as',
#   'a',
#   'feature',
#   'request',
#   'at',
#   'tanuj'],
#  ['are',
#   'there',
#   'any',
#   'plans',
#   'to',
#   'add',
#   'a',
#   'fast',
#   'crop',
#   'mode',
#   'for',
#   'the',
#   'ipad',
#   'version',
#   'of',
#   'lr',
#   'it',
#   'takes',
#   'too',
#   'many',
#   'taps',
#   'and',
#   'slows',
#   'down',
#   'workflow'],
#  ['thanks',
#   'for',
#   'sharing',
#   'the',
#   'file',
#   'well',
#   'get',
#   'back',
#   'to',
#   'you',
#   'with',
#   'updates',
#   'as',
#   'we',
#   'investigate',
#   'wren'],
#  ['it’s',
#   'intermittent',
#   'for',
#   'me',
#   'this',
#   'file',
#   'fails',
#   'reliably',
#   'the',
#   '“create',
#   'subfolder”',
#   'option',
#   'just',
#   'makes',
#   'an',
#   'empty',
#   '“svg”',
#   'folder'],
#  ['unfortunately',
#   'we',
#   'are',
#   'not',
#   'able',
#   'to',
#   'reproduce',
#   'it',
#   'at',
#   'our',
#   'end',
#   'ill',
#   'still',
#   'be',
#   'checking',
#   'with',
#   'the',
#   'development',
#   'team',
#   'to',
#   'find',
#   'out',
#   'more',
#   'on',
#   'this',
#   'om'],
#  ['seems',
#   'pretty',
#   'widespread',
#   'dont',
#   'mean',
#   'to',
#   'be',
#   'a',
#   'jerk',
#   'but',
#   'its',
#   'frustrating',
#   'when',
#   'an',
#   'update',
#   'breaks',
#   'core',
#   'functionality'],
#  ['hi',
#   'keelin',
#   'sorry',
#   'for',
#   'the',
#   'inconvenience',
#   'i',
#   'am',
#   'able',
#   'to',
#   'export',
#   'svg',
#   'in',
#   'ai',
#   'cc',
#   '2018',
#   'would',
#   'you',
#   'mind',
#   'sharing',
#   'your',
#   'workflow',
#   'sample',
#   'filescreenshot'],
#  ['so',
#   'apparently',
#   'the',
#   'new',
#   'version',
#   'of',
#   'has',
#   'this',
#   'cool',
#   'feature',
#   'where',
#   'you',
#   'cant',
#   'export',
#   'svgs',
#   'sick',
#   'update',
#   'guys'],
#  ['hi',
#   'duncan',
#   'please',
#   'update',
#   'lightroom',
#   'to',
#   '613',
#   'from',
#   'the',
#   'following',
#   'link',
#   'tanuj'],
#  ['im',
#   'worried',
#   'as',
#   'if',
#   'i',
#   'update',
#   'my',
#   'lr6',
#   'standalone',
#   'programme',
#   'i',
#   'could',
#   'lose',
#   'it',
#   'due',
#   'to',
#   'the',
#   'new',
#   'online',
#   'versionis',
#   'this',
#   'true',
#   'and',
#   'if',
#   'so',
#   'is',
#   'this',
#   'fair'],
#  ['whoa',
#   'come',
#   'along',
#   'with',
#   'lightroom’s',
#   'own',
#   'ben',
#   'warde',
#   'to',
#   'get',
#   'the',
#   'lowdown'],
#  ['hi',
#   'lauren',
#   'can',
#   'you',
#   'try',
#   'changing',
#   'your',
#   'forum',
#   'screen',
#   'name',
#   'at',
#   'that',
#   'should',
#   'do',
#   'the',
#   'trick',
#   'madison'],
#  ['your',
#   'online',
#   'forum',
#   'is',
#   'always',
#   'broken',
#   'even',
#   'when',
#   'i',
#   'clear',
#   'my',
#   'cookies'],
#  ['hi',
#   'jake',
#   'any',
#   'screenshots',
#   'you',
#   'can',
#   'share',
#   'what',
#   'are',
#   'you',
#   'export',
#   'settings',
#   'is',
#   'this',
#   'happening',
#   'on',
#   'all',
#   'files',
#   'with',
#   'links',
#   'wren'],
#  ['here',
#   'is',
#   'an',
#   'example',
#   'of',
#   'an',
#   'export',
#   'before',
#   'and',
#   'after',
#   'export',
#   'settings',
#   'are',
#   'unchanged',
#   'from',
#   'default',
#   'no',
#   'only',
#   'some',
#   'files'],
#  ['hi',
#   'jack',
#   'is',
#   'there',
#   'any',
#   'way',
#   'you',
#   'could',
#   'send',
#   'me',
#   'a',
#   'file',
#   'to',
#   'try',
#   'exporting',
#   'on',
#   'my',
#   'end',
#   'to',
#   'try',
#   'and',
#   'replicate',
#   'wren'],
#  ['hi',
#   'jack',
#   'were',
#   'looping',
#   'the',
#   'expert',
#   'back',
#   'into',
#   'this',
#   'conversation',
#   'thanks',
#   'aj'],
#  ['solved', 'this', 'via', 'phone', 'support'],
#  ['indesign',
#   '130',
#   'is',
#   'exporting',
#   'all',
#   'pdfs',
#   'with',
#   'blurry',
#   'links',
#   'but',
#   'links',
#   'are',
#   'not',
#   'missing',
#   'in',
#   'indd',
#   'file',
#   'jpg',
#   'export',
#   'is',
#   'not',
#   'blurry',
#   'help'],
#  ['thank',
#   'you',
#   'for',
#   'that',
#   'we',
#   'have',
#   'responded',
#   'to',
#   'your',
#   'dm',
#   'with',
#   'more',
#   'information'],
#  ['ive',
#   'just',
#   'sent',
#   'you',
#   'a',
#   'message',
#   'with',
#   'details',
#   'thanks',
#   'for',
#   'your',
#   'help'],
#  ['hi',
#   'there',
#   'we',
#   'would',
#   'like',
#   'to',
#   'help',
#   'please',
#   'dm',
#   'us',
#   'your',
#   'accounts',
#   'email',
#   'and',
#   'reservation',
#   'code',
#   'so',
#   'we',
#   'can',
#   'further',
#   'assist',
#   'thank',
#   'you'],
#  ['quand',
#   'ton',
#   'ne',
#   'ressemble',
#   'pas',
#   'à',
#   'celui',
#   'que',
#   'tu',
#   'as',
#   'réservé',
#   'amp',
#   'quen',
#   'dêtre',
#   'sale',
#   'et',
#   'en',
#   'soussol',
#   'tu',
#   'te',
#   'retrouves',
#   'à',
#   '10',
#   'dans',
#   '1',
#   'logement'],
#  ['we',
#   'are',
#   'sorry',
#   'to',
#   'hear',
#   'this',
#   'please',
#   'dm',
#   'your',
#   'email',
#   'address',
#   'and',
#   'reservation',
#   'code',
#   'so',
#   'we',
#   'can',
#   'look',
#   'into',
#   'this',
#   'for',
#   'you',
#   'thank',
#   'you'],
#  ['misrepresentation',
#   'by',
#   'host',
#   'asked',
#   'them',
#   'to',
#   'cancel',
#   'my',
#   'reservation',
#   'and',
#   'refund',
#   'me',
#   'over',
#   'aud1700',
#   'strict',
#   'policy',
#   'no',
#   'response',
#   'please',
#   'help'],
#  ['hi',
#   'there',
#   'wed',
#   'recommend',
#   'reaching',
#   'out',
#   'to',
#   'the',
#   'chat',
#   'team',
#   'here',
#   'ja'],
#  ['they', 'have', 'no', 'info', 'either'],
#  ['wed',
#   'recommend',
#   'keeping',
#   'an',
#   'eye',
#   'out',
#   'on',
#   'your',
#   'email',
#   'that',
#   'is',
#   'associated',
#   'with',
#   'your',
#   'account',
#   'for',
#   'further',
#   'info',
#   'ja'],
#  ['lol',
#   'so',
#   'theres',
#   'no',
#   'one',
#   'who',
#   'can',
#   'say',
#   'when',
#   'theyre',
#   'going',
#   'to',
#   'be',
#   'shipped',
#   'thats',
#   'kinda',
#   'weird'],
#  ['when',
#   'someone',
#   'or',
#   'knows',
#   'when',
#   'the',
#   'xbox',
#   'one',
#   'x',
#   'ships',
#   'let',
#   'us',
#   'know',
#   'lol',
#   'shouldnt',
#   'b',
#   'a',
#   'mystery'],
#  ['did',
#   'you',
#   'preorder',
#   'this',
#   'console',
#   'via',
#   'the',
#   'microsoft',
#   'store',
#   'if',
#   'so',
#   'then',
#   'lets',
#   'have',
#   'you',
#   'reach',
#   'out',
#   'here',
#   'ja'],
#  ['kinda',
#   'need',
#   'to',
#   'make',
#   'sure',
#   'i',
#   'have',
#   '680',
#   'cdn',
#   'in',
#   'my',
#   'bank',
#   'so',
#   'would',
#   'be',
#   'nice',
#   'to',
#   'know',
#   'i',
#   'dun',
#   'just',
#   'have',
#   'cash',
#   'laying',
#   'around',
#   'ya',
#   'know',
#   'reallifestruggles'],
#  ['already',
#   'did',
#   'they',
#   'had',
#   'me',
#   'call',
#   'and',
#   'no',
#   'one',
#   'can',
#   'answer',
#   'the',
#   'question',
#   'im',
#   'not',
#   'trying',
#   'to',
#   'be',
#   'a',
#   'jerk',
#   'but',
#   'its',
#   'nuts',
#   'no',
#   'one',
#   'has',
#   'a',
#   'answer'],
#  ['would',
#   'like',
#   'to',
#   'know',
#   'so',
#   'i',
#   'can',
#   'make',
#   'sure',
#   'i',
#   'have',
#   'enough',
#   'money',
#   'for',
#   'it'],
#  ['can',
#   'anyone',
#   'let',
#   'me',
#   'know',
#   'when',
#   'our',
#   'pre',
#   'orders',
#   'are',
#   'going',
#   'to',
#   'be',
#   'shipped',
#   'for',
#   'xbox',
#   'one',
#   'x'],
#  ['hello',
#   'would',
#   'you',
#   'mind',
#   'following',
#   'us',
#   'and',
#   'sending',
#   'a',
#   'dm',
#   'with',
#   'your',
#   'gamertag',
#   'and',
#   'the',
#   'code',
#   'you',
#   'redeemed',
#   'rr'],
#  ['redeemed',
#   'a',
#   'code',
#   'for',
#   'fifa',
#   'points',
#   'this',
#   'afternoon',
#   'and',
#   'still',
#   'havent',
#   'got',
#   'it',
#   'why',
#   'is',
#   'this'],
#  ['can',
#   'you',
#   'show',
#   'us',
#   'what',
#   'is',
#   'appearing',
#   'on',
#   'your',
#   'screen',
#   'rm'],
#  ['this',
#   'is',
#   'whats',
#   'on',
#   'my',
#   'screen',
#   'not',
#   'sure',
#   'if',
#   'its',
#   'xbox',
#   'side',
#   'or',
#   'my5',
#   'side',
#   'thats',
#   'broken',
#   'last',
#   'time',
#   'it',
#   'was',
#   'my5',
#   'as',
#   'had',
#   'to',
#   'call',
#   'head',
#   'office',
#   'about',
#   'it'],
#  ['the',
#   '5',
#   'app',
#   'on',
#   'xboxes',
#   'not',
#   'working',
#   'error',
#   'code',
#   '200',
#   'done',
#   'a',
#   'power',
#   'cycle',
#   'and',
#   'still',
#   'the',
#   'same',
#   'please',
#   'fix',
#   'app'],
#  ['ご不便をおかけしております。アプリをご利用でしょうか。強制停止gt端末の再起動にて改善する場合がございますので、お試しください。改善しない場合は、状況を確認しご案内させていただきますのでこちらからカスタマーサービスまでご連絡ください。',
#   'et'],
#  ['amazonプライムビデオ、再生エラーが多いです'],
#  ['hi',
#   'emergency',
#   'services',
#   'are',
#   'dealing',
#   'with',
#   'an',
#   'incident',
#   'info',
#   'here'],
#  ['my',
#   'colleagues',
#   'for',
#   'more',
#   'info',
#   'on',
#   'how',
#   'this',
#   'is',
#   'affecting',
#   'services',
#   'thanks',
#   '22',
#   'jp'],
#  ['ah', 'maybe', 'could', 'help', 'on', 'this', 'one'],
#  ['nothing',
#   'partner',
#   'was',
#   'on',
#   'a',
#   'train',
#   'to',
#   'preston',
#   'had',
#   'to',
#   'get',
#   'a',
#   'taxi',
#   'rest',
#   'of',
#   'way',
#   'as',
#   'was',
#   'told',
#   'no',
#   'trains',
#   'into',
#   'preston',
#   'for',
#   'a',
#   'few',
#   'hours'],
#  ['what', 'have', 'you', 'seen'],
#  ['something', 'going', 'on', 'at', 'preston', 'train', 'station'],
#  ['hi',
#   'loreenkindly',
#   'dm',
#   'us',
#   'your',
#   'booking',
#   'number',
#   'and',
#   'attach',
#   'guest',
#   'passport',
#   'copy',
#   'well',
#   'fix',
#   'it',
#   'for',
#   'you',
#   'see',
#   'you',
#   'there',
#   'anwar'],
#  ['hi',
#   'i',
#   'have',
#   'dm',
#   'u',
#   'my',
#   'booking',
#   'and',
#   'passport',
#   'picture',
#   'thanks',
#   'so',
#   'much',
#   'for',
#   'quick',
#   'action'],
#  ['hi',
#   'loreencorrection',
#   'done',
#   'see',
#   'you',
#   'on',
#   'board',
#   'cheers',
#   'anwar'],
#  ['thank', 'you', 'very', 'much'],
#  ['hi',
#   'i',
#   'would',
#   'like',
#   'to',
#   'know',
#   'on',
#   'my',
#   'itenerary',
#   'on',
#   'how',
#   'the',
#   'birthday',
#   'can',
#   'be',
#   'seen',
#   'i',
#   'would',
#   'like',
#   'to',
#   'double',
#   'check',
#   'if',
#   'i',
#   'can',
#   'key',
#   'in',
#   'our',
#   'birthdays',
#   'right'],
#  ['hi',
#   'loreen',
#   'you',
#   'may',
#   'check',
#   'the',
#   'passengers',
#   'date',
#   'of',
#   'birth',
#   'via',
#   'airasia',
#   'member',
#   'account',
#   'under',
#   'manage',
#   'booking',
#   'thankssha'],
#  ['but',
#   'i',
#   'cant',
#   'see',
#   'it',
#   'i',
#   'only',
#   'see',
#   'itenerary',
#   'no',
#   'birthday'],
#  ['as',
#   'you',
#   'may',
#   'check',
#   'it',
#   'under',
#   'manage',
#   'my',
#   'booking',
#   'online',
#   'or',
#   'during',
#   'web',
#   'check',
#   'in',
#   'date',
#   'of',
#   'birth',
#   'will',
#   'be',
#   'shown',
#   'accordingly',
#   'ed'],
#  ['hi',
#   'airasia',
#   'i',
#   'want',
#   'to',
#   'rebook',
#   'my',
#   'return',
#   'flight',
#   'but',
#   'when',
#   'i',
#   'try',
#   'rebooking',
#   'my',
#   'inbond',
#   'also',
#   'is',
#   'rebooking',
#   'please',
#   'help',
#   'me',
#   'thanks'],
#  ['hi',
#   'loreen',
#   'kindly',
#   'dm',
#   'us',
#   'the',
#   'booking',
#   'number',
#   'that',
#   'you',
#   'wish',
#   'to',
#   'do',
#   'change',
#   'flight',
#   'for',
#   'us',
#   'to',
#   'assist',
#   'you',
#   'furtherthanksanwar'],
#  ['hi',
#   'i',
#   'have',
#   'booked',
#   'my',
#   'ticket',
#   'and',
#   'when',
#   'i',
#   'see',
#   'my',
#   'itenary',
#   'has',
#   'been',
#   'redundant',
#   'i',
#   'call',
#   'ur',
#   'customer',
#   'service',
#   'to',
#   'assist',
#   'but',
#   'out',
#   'of',
#   'line'],
#  ['sorry',
#   'as',
#   'we',
#   'checked',
#   'booking',
#   'has',
#   'already',
#   'expired',
#   'due',
#   'to',
#   'no',
#   'payment',
#   'made',
#   'kindly',
#   'please',
#   'proceed',
#   'with',
#   'new',
#   'booking',
#   'ed'],
#  ['lost',
#   'my',
#   'booking',
#   'chua',
#   'loreen',
#   'lee',
#   'flight',
#   'z2',
#   '129128',
#   '1222018',
#   'taipeimanila',
#   'email'],
#  ['lost',
#   'your',
#   'booking',
#   'number',
#   'no',
#   'worries',
#   'just',
#   'drop',
#   'me',
#   'the',
#   'passengers',
#   'name',
#   'flight',
#   'details',
#   'and',
#   'email',
#   'ill',
#   'trace',
#   'it',
#   'and',
#   'email',
#   'u',
#   'in',
#   'no',
#   'time'],
#  ['hi',
#   'emma',
#   'could',
#   'you',
#   'please',
#   'follow',
#   'us',
#   'so',
#   'we',
#   'can',
#   'dm',
#   'you',
#   'again',
#   'with',
#   'the',
#   'email',
#   'reply',
#   'sent',
#   'to',
#   'you',
#   'yana'],
#  ['hi', 'yana', 'followed'],
#  ['hi',
#   'emma',
#   'we',
#   'have',
#   'replied',
#   'to',
#   'you',
#   'via',
#   'dm',
#   'please',
#   'check',
#   'again',
#   'thank',
#   'you',
#   'mariya'],
#  ['hi',
#   'yana',
#   'i',
#   'don’t',
#   'have',
#   'any',
#   'dms',
#   'from',
#   'you',
#   'did',
#   'you',
#   'mean',
#   'email'],
#  ['we',
#   'have',
#   'replied',
#   'to',
#   'you',
#   'via',
#   'dm',
#   'check',
#   'it',
#   'out',
#   'yana'],
#  ['cas19708536cb92n2',
#   'crm0326600',
#   'please',
#   'check',
#   'on',
#   'this',
#   'i',
#   'havent',
#   'heard',
#   'from',
#   'my',
#   'case',
#   'officer',
#   'in',
#   'weeks',
#   'and',
#   'provided',
#   'all',
#   'docs'],
#  ['notified', 'if', 'there', 'should', 'be', 'any', 'changesyana'],
#  ['youll',
#   'be',
#   'even',
#   'happier',
#   'to',
#   'know',
#   'that',
#   'the',
#   'restrictions',
#   'around',
#   'the',
#   'volcano',
#   'area',
#   'have',
#   'been',
#   'lifted',
#   'enjoy',
#   'staying',
#   'at',
#   'home',
#   'pal',
#   'unlucky'],
#  ['why',
#   'are',
#   'you',
#   'not',
#   'refunding',
#   'my',
#   'trip',
#   'to',
#   'bali',
#   'for',
#   'volcano',
#   'eruption',
#   'urgently',
#   'refund'],
#  ['we',
#   'are',
#   'terribly',
#   'sorry',
#   'but',
#   'we',
#   'could',
#   'not',
#   'offer',
#   'any',
#   'options',
#   'since',
#   'all',
#   'the',
#   'flight',
#   'are',
#   'operating',
#   'as',
#   'per',
#   'normalpassengers',
#   'will',
#   'be'],
#  ['hi',
#   'looreen',
#   'kindly',
#   'dm',
#   'us',
#   'the',
#   'booking',
#   'number',
#   'and',
#   'attach',
#   'guest',
#   'passport',
#   'copy',
#   'well',
#   'fix',
#   'it',
#   'for',
#   'you',
#   'see',
#   'you',
#   'there',
#   'anwar'],
#  ['my',
#   'surname',
#   'has',
#   'been',
#   'redundant',
#   'where',
#   'do',
#   'i',
#   'go',
#   'to',
#   'correct',
#   'it'],
#  ['h'],
#  ['please',
#   'dont',
#   'tell',
#   'me',
#   'carol',
#   'i',
#   'cant',
#   'wait',
#   'to',
#   'go',
#   'home',
#   'amp',
#   'find',
#   'out',
#   'chloe'],
#  ['my', 'lips', 'are', 'sealed'],
#  ['somebody', 'else', 'has', 'told', 'me', 'im', 'gutted', 'chloe'],
#  ['aahhrrgh', 'keep', 'mum', 'i’m', 'still', 'watching'],
#  ['dont', 'you', 'worry', 'carol', 'my', 'lips', 'are', 'shut', 'chloe'],
#  ['aww', 'sophie', 'deserved', 'winner'],
#  ['fresh',
#   'cream',
#   'palmier',
#   'bakery',
#   'bellshill',
#   'gets',
#   'my',
#   'vote',
#   'for',
#   'star',
#   'baker',
#   '\u200djust',
#   'catching',
#   'up',
#   'on',
#   'gbbo17',
#   'don’t',
#   'know',
#   'who',
#   'won',
#   'yet'],
#  ['hi',
#   'there',
#   'sorry',
#   'about',
#   'that',
#   'please',
#   'dm',
#   'me',
#   'when',
#   'you',
#   'visited',
#   'the',
#   'store',
#   'and',
#   'ill',
#   'look',
#   'into',
#   'this',
#   'thanks',
#   'kirsty'],
#  ['thats',
#   'pointless',
#   'as',
#   'its',
#   'every',
#   'day',
#   'all',
#   'the',
#   'time',
#   'no',
#   'matter',
#   'when',
#   'i',
#   'go',
#   'in',
#   'i',
#   'speak',
#   '2the',
#   'management',
#   'who',
#   'r',
#   'as',
#   'fed',
#   'up',
#   'as',
#   'i',
#   'am',
#   'theyve',
#   'no',
#   'staff'],
#  ['so',
#   'sorry',
#   'could',
#   'you',
#   'send',
#   'me',
#   'what',
#   'store',
#   'this',
#   'is',
#   'in',
#   'so',
#   'we',
#   'can',
#   'get',
#   'this',
#   'to',
#   'the',
#   'right',
#   'people',
#   'janay'],
#  ['i',
#   'can',
#   'see',
#   'youve',
#   'sent',
#   'the',
#   'store',
#   'leave',
#   'it',
#   'with',
#   'us',
#   'and',
#   'well',
#   'get',
#   'this',
#   'sorted',
#   'janay'],
#  ['so',
#   'fed',
#   'up',
#   'of',
#   'this',
#   'very',
#   'familiar',
#   'sight',
#   'at',
#   'houghton',
#   'regis',
#   'get',
#   'more',
#   'staff',
#   'amp',
#   'stock',
#   'the',
#   'place',
#   'properly',
#   'this',
#   'is',
#   'just',
#   'a',
#   'small',
#   'example'],
#  ['store',
#   'you',
#   'bought',
#   'it',
#   'from',
#   'along',
#   'with',
#   'your',
#   'address',
#   'and',
#   'more',
#   'card',
#   'number',
#   'and',
#   'ill',
#   'get',
#   'this',
#   'sorted',
#   'for',
#   'you',
#   'thanks',
#   'kirsty'],
#  ['3',
#   'for',
#   '£6',
#   'unless',
#   'one',
#   'is',
#   'reduced',
#   'hidden',
#   'label',
#   'on',
#   'the',
#   'side',
#   'then',
#   'it’s',
#   '3',
#   'for',
#   '£614',
#   'don’t',
#   'care',
#   'about',
#   'the',
#   '14p',
#   'but',
#   'feel',
#   'ripped',
#   'off'],
#  ['hi',
#   'emma',
#   'sorry',
#   'about',
#   'that',
#   'if',
#   'a',
#   'product',
#   'is',
#   'reduced',
#   'then',
#   'the',
#   'previous',
#   'offer',
#   'isnt',
#   'applied',
#   'please',
#   'dm',
#   'me',
#   'the',
#   'barcode',
#   'and',
#   'the'],
#  ['youre',
#   'welcome',
#   'william',
#   'give',
#   'us',
#   'a',
#   'shout',
#   'if',
#   'you',
#   'need',
#   'assistance',
#   'with',
#   'anything',
#   'else',
#   'good',
#   'luck',
#   'with',
#   'the',
#   'nrc',
#   'app'],
#  ['thank', 'you', 'nike'],
#  ['while',
#   'the',
#   'coach',
#   'plans',
#   'can',
#   'be',
#   'weeks',
#   'in',
#   'time',
#   'its',
#   'up',
#   'to',
#   'you',
#   'to',
#   'decide',
#   'what',
#   'fits',
#   'you',
#   'best',
#   '22'],
#  ['im',
#   'new',
#   'to',
#   'nike',
#   'run',
#   'club',
#   'app',
#   'should',
#   'i',
#   'start',
#   'with',
#   'guided',
#   'runs',
#   'or',
#   'my',
#   'couch'],
#  ['we',
#   'got',
#   'this',
#   'both',
#   'are',
#   'beneficial',
#   'to',
#   'starting',
#   'the',
#   'nrc',
#   'app',
#   'the',
#   'audio',
#   'guided',
#   'runs',
#   'are',
#   'one',
#   'time',
#   'runs',
#   '12'],
#  ['what', 'exactly', 'is', 'the', 'issue', 'you', 'are', 'having'],
#  ['i’ve',
#   'asked',
#   'your',
#   'sales',
#   'rep',
#   'about',
#   'the',
#   'payments',
#   'and',
#   'she',
#   'wasn’t',
#   'ready',
#   'to',
#   'listen',
#   'to',
#   'any',
#   'issues',
#   'that',
#   'i',
#   'had'],
#  ['apologies',
#   'for',
#   'all',
#   'of',
#   'the',
#   'issues',
#   'if',
#   'you',
#   'have',
#   'time',
#   'to',
#   'chat',
#   'securely',
#   'with',
#   'me',
#   'i',
#   'would',
#   'be',
#   'happy',
#   'to',
#   'review',
#   'rachel'],
#  ['sure', 'please', 'drop', 'me', 'a', 'message', 'now'],
#  ['great',
#   'please',
#   'go',
#   'to',
#   'log',
#   'in',
#   'and',
#   'select',
#   'code',
#   '10307',
#   'and',
#   'we',
#   'will',
#   'continue',
#   'our',
#   'conversation',
#   'there',
#   'rk'],
#  ['amex', 'platinum', 'and', 'amex', 'everyday', 'card'],
#  ['i',
#   'am',
#   'so',
#   'sorry',
#   'to',
#   'hear',
#   'that',
#   'which',
#   'us',
#   'based',
#   'card',
#   'do',
#   'you',
#   'have',
#   'pls',
#   'do',
#   'not',
#   'share',
#   'any',
#   'personal',
#   'info'],
#  ['nope',
#   'they',
#   'weren’t',
#   'ready',
#   'to',
#   'listen',
#   'what',
#   'i',
#   'wanted',
#   'to',
#   'say',
#   'and',
#   'if',
#   'i',
#   'had',
#   'any',
#   'questions',
#   'about',
#   'anything',
#   'else',
#   'and',
#   'hung',
#   'up',
#   'on',
#   'me'],
#  ['hi',
#   'there',
#   'i',
#   'am',
#   'so',
#   'sorry',
#   'to',
#   'her',
#   'that',
#   'what',
#   'exactly',
#   'is',
#   'the',
#   'issue',
#   'you',
#   'are',
#   'having'],
#  ['thought',
#   'amex',
#   'values',
#   'their',
#   'customers',
#   'but',
#   'boy',
#   'you',
#   'got',
#   'really',
#   'bad',
#   'reps',
#   'on',
#   'the',
#   'customer',
#   'service'],
#  ['it’s',
#   'getting',
#   'all',
#   'sorts',
#   'of',
#   'saucy',
#   'over',
#   'here',
#   'this',
#   'halloween',
#   'trickortweet'],
#  ['treat'],
#  ['so',
#   'what’ll',
#   'it',
#   'be',
#   'this',
#   'halloween',
#   'a',
#   'trick',
#   'or',
#   'a',
#   'treat',
#   'let',
#   'us',
#   'know',
#   'below',
#   'trickortweet'],
#  ['our',
#   'heart’s',
#   'beating',
#   'faster',
#   'over',
#   'here',
#   'and',
#   'it’s',
#   'not',
#   'from',
#   'all',
#   'the',
#   'scares',
#   'trickortweet'],
#  ['treat', 'me'],
#  ['chocolate',
#   'chip',
#   'cookies',
#   'mcflurry',
#   'everything',
#   'you’ve',
#   'ever',
#   'been',
#   'missing',
#   'trickortweet'],
#  ['can', 'i', 'get', 'uhhhhhhhhhh', 'treat'],
#  ['hi',
#   'are',
#   'you',
#   'receiving',
#   'an',
#   'error',
#   'message',
#   'when',
#   'trying',
#   'to',
#   'link',
#   'the',
#   'account'],
#  ['i',
#   'cant',
#   'connect',
#   'my',
#   'interactive',
#   'broker',
#   'canada',
#   'with',
#   'yahoo',
#   'finance',
#   'app',
#   'in',
#   'ios',
#   '11',
#   'any',
#   'suggestions'],
#  ['hi',
#   'there',
#   'thanks',
#   'for',
#   'reaching',
#   'out',
#   'please',
#   'send',
#   'us',
#   'a',
#   'dm',
#   'so',
#   'we',
#   'can',
#   'continue',
#   'our',
#   'conversation'],
#  ['i',
#   'have',
#   'to',
#   'be',
#   'at',
#   'work',
#   'at',
#   '2pm',
#   'tomorrow',
#   'my',
#   'new',
#   'phone',
#   'is',
#   'being',
#   'overnighted',
#   'but',
#   'it',
#   'may',
#   'not',
#   'be',
#   'there',
#   'until',
#   'then',
#   'i',
#   'have',
#   'no',
#   'other',
#   'ride'],
#  ['please',
#   'let',
#   'us',
#   'know',
#   'how',
#   'we',
#   'can',
#   'help',
#   'and',
#   'dm',
#   'your',
#   'tracking',
#   'using',
#   'this',
#   'link',
#   'mc'],
#  ['whats', 'wrong', 'w', 'amazon', 'leavin', 'shit', 'outside', 'like', 'ups'],
#  ['im',
#   'sorry',
#   'to',
#   'hear',
#   'that',
#   'let',
#   'us',
#   'know',
#   'what',
#   'happened',
#   'and',
#   'if',
#   'you',
#   'have',
#   'a',
#   'tracking',
#   'please',
#   'send',
#   'that',
#   'too',
#   'mc'],
#  ['that', 'small', 'biz', 'tyrant', 'a', 'dime', 'yo', 'nice'],
#  ['worth',
#   'the',
#   'squeeze',
#   'when',
#   'you’ve',
#   'got',
# ...
#   'to',
#   'the',
#   'merchants',
#   'site',
#   'to',
#   'make',
#   'the',
#   'purchase',
#   'bg'],
#  ['sounds', 'good', 'thanks'],
#  ['hi',
#   'do',
#   'i',
#   'have',
#   'to',
#   'go',
#   'through',
#   'the',
#   'chase',
#   'online',
#   'ultimate',
#   'rewards',
#   'webpage',
#   'to',
#   'get',
#   'the',
#   'extra',
#   'cash',
#   'back',
#   'when',
#   'i',
#   'shop'],
#  ['12',
#   'hello',
#   'in',
#   'order',
#   'to',
#   'get',
#   'the',
#   'cash',
#   'back',
#   'youll',
#   'need',
#   'to',
#   'click',
#   'the',
#   'link',
#   'from',
#   'the',
#   'ultimate',
#   'rewards',
#   'website',
#   'youll',
#   'be',
#   'routed'],
#  ['we',
#   'appreciate',
#   'the',
#   'kind',
#   'words',
#   'if',
#   'you',
#   'have',
#   'questions',
#   'or',
#   'concerns',
#   'please',
#   'let',
#   'us',
#   'know',
#   'were',
#   'here',
#   'to',
#   'help',
#   'cr'],
#  ['ive',
#   'had',
#   'some',
#   'ups',
#   'and',
#   'downs',
#   'from',
#   'banking',
#   'with',
#   'chase',
#   'but',
#   'lately',
#   'theyve',
#   'been',
#   'really',
#   'good',
#   'to',
#   'me',
#   'so',
#   'shoutout',
#   'to',
#   'you',
#   '✊'],
#  ['i’d',
#   'like',
#   'to',
#   'review',
#   'this',
#   'further',
#   'for',
#   'you',
#   'could',
#   'you',
#   'please',
#   'dm',
#   'your',
#   'name',
#   'amp',
#   'zip',
#   'code',
#   'bg'],
#  ['hey',
#   'were',
#   'gonna',
#   'need',
#   'to',
#   'talk',
#   'about',
#   'all',
#   'these',
#   'pending',
#   'charges',
#   'that',
#   'keep',
#   'going',
#   'through',
#   'my',
#   'account',
#   '5',
#   'days',
#   'after',
#   'the',
#   'transaction',
#   'was',
#   'made',
#   'im',
#   'getting',
#   'real',
#   'irritated'],
#  ['were', 'glad', 'we', 'were', 'able', 'to', 'help', 'jg'],
#  ['just',
#   'got',
#   'off',
#   'the',
#   'phone',
#   'with',
#   'them',
#   'you',
#   'guys',
#   'were',
#   'great'],
#  ['aw',
#   'its',
#   'our',
#   'pleasure',
#   'to',
#   'help',
#   'let',
#   'us',
#   'know',
#   'if',
#   'we',
#   'can',
#   'be',
#   'of',
#   'additional',
#   'assistance',
#   'jg'],
#  ['thanks', 'guys'],
#  ['we',
#   'would',
#   'be',
#   'happy',
#   'to',
#   'look',
#   'into',
#   'this',
#   'for',
#   'you',
#   'could',
#   'you',
#   'dm',
#   'your',
#   'name',
#   'and',
#   'zip',
#   'code',
#   'jg'],
#  ['i',
#   'couldnt',
#   'find',
#   'an',
#   'email',
#   'online',
#   'you',
#   'have',
#   'my',
#   'apartment',
#   'address',
#   'but',
#   'not',
#   'my',
#   'number',
#   'how',
#   'can',
#   'i',
#   'update',
#   'that',
#   'to',
#   'ensure',
#   'the',
#   'card',
#   'gets',
#   'to',
#   'me'],
#  ['i',
#   'applied',
#   'for',
#   'a',
#   'credit',
#   'card',
#   'and',
#   'but',
#   'i',
#   'was',
#   'never',
#   'asked',
#   'for',
#   'my',
#   'apt',
#   'tried',
#   'calling',
#   'but',
#   'couldnt',
#   'get',
#   'past',
#   'your',
#   'automated',
#   'system'],
#  ['hello',
#   'this',
#   'does',
#   'not',
#   'sound',
#   'good',
#   'can',
#   'you',
#   'dm',
#   'the',
#   'account',
#   'name',
#   'and',
#   'complete',
#   'service',
#   'address',
#   'we',
#   'would',
#   'like',
#   'to',
#   'help',
#   'dan'],
#  ['had',
#   'to',
#   'push',
#   'hard',
#   'but',
#   'finally',
#   'got',
#   'a',
#   'team',
#   'lead',
#   'to',
#   'reach',
#   'out',
#   'to',
#   'oncall',
#   'tech',
#   'outage',
#   'issue',
#   'solved',
#   'csissue',
#   'not',
#   'csfail'],
#  ['next',
#   'day',
#   'turnaround',
#   'on',
#   'an',
#   'outage',
#   'issue',
#   'for',
#   'the',
#   'csfail',
#   'when',
#   'it',
#   'comes',
#   'to',
#   'dealing',
#   'with',
#   'outages',
#   'csfail',
#   'outageprobs'],
#  ['hi',
#   'fɍ1sꝁɇnsŧɇɨn',
#   'please',
#   'dm',
#   'account',
#   'info',
#   'including',
#   'street',
#   'address',
#   'so',
#   'we',
#   'can',
#   'look',
#   'into',
#   'this',
#   'greg'],
#  ['it', 'needs', 'to', 'be', 'fixed', 'permanently', 'now'],
#  ['i',
#   'dont',
#   'want',
#   'you',
#   'to',
#   'feel',
#   'this',
#   'way',
#   'whats',
#   'going',
#   'on',
#   'colleen'],
#  ['so',
#   'is',
#   'back',
#   'fucking',
#   'me',
#   'again',
#   'with',
#   'my',
#   'business',
#   'plan',
#   'internet',
#   'super',
#   'cool',
#   'company',
#   'i',
#   'dont',
#   'recommend'],
#  ['hello',
#   'this',
#   'does',
#   'not',
#   'sound',
#   'good',
#   'can',
#   'you',
#   'dm',
#   'the',
#   'account',
#   'name',
#   'and',
#   'complete',
#   'service',
#   'address',
#   'we',
#   'would',
#   'like',
#   'to',
#   'help',
#   'dan'],
#  ['i’d',
#   'like',
#   'at',
#   'least',
#   'one',
#   'month',
#   'to',
#   'go',
#   'by',
#   'where',
#   'i',
#   'don’t',
#   'have',
#   'to',
#   'say',
#   'how',
#   'crappy',
#   'the',
#   'service',
#   'is',
#   'with',
#   'in',
#   'vegas',
#   'amp',
#   'how',
#   'much',
#   'i',
#   'despise',
#   'them'],
#  ['hi',
#   'jeanclaude',
#   'i',
#   'hope',
#   'you',
#   'do',
#   'not',
#   'have',
#   'any',
#   'service',
#   'interruptions',
#   'if',
#   'you',
#   'need',
#   'assistance',
#   'reach',
#   'out',
#   'to',
#   'us',
#   'mike'],
#  ['i', 'just', 'did'],
#  ['hi',
#   'the',
#   'outage',
#   'is',
#   'still',
#   'open',
#   'in',
#   'your',
#   'area',
#   'and',
#   'working',
#   'to',
#   'get',
#   'it',
#   'restored',
#   'as',
#   'quickly',
#   'as',
#   'possible',
#   'thanks',
#   'for',
#   'your',
#   'patience',
#   'mary'],
#  ['been',
#   'lookong',
#   'forward',
#   'to',
#   'binge',
#   'on',
#   'strangerthingsseason2',
#   'just',
#   'hope',
#   'we',
#   'have',
#   'internet',
#   'a',
#   'lot',
#   'of',
#   'outages',
#   'in',
#   'the',
#   'neighborhood',
#   'lately'],
#  ['okay',
#   'great',
#   'if',
#   'you',
#   'have',
#   'any',
#   'further',
#   'concerns',
#   'please',
#   'reach',
#   'out',
#   'to',
#   'us',
#   'xavier'],
#  ['seems',
#   'like',
#   'my',
#   'problem',
#   'has',
#   'been',
#   'resolved',
#   'the',
#   'technicians',
#   'you',
#   'sent',
#   'to',
#   'the',
#   'house',
#   'were',
#   'very',
#   'capable',
#   'and',
#   'surpassed',
#   'expectations'],
#  ['have',
#   'you',
#   'asked',
#   'the',
#   'seller',
#   'yet',
#   'where',
#   'it',
#   'is',
#   'see',
#   'as',
#   'they',
#   'may',
#   'be',
#   'able',
#   'to',
#   'help',
#   'out',
#   'd'],
#  ['i',
#   'have',
#   'contacted',
#   'seller',
#   'but',
#   'my',
#   'question',
#   'to',
#   'you',
#   'is',
#   'when',
#   'will',
#   'i',
#   'receive',
#   'my',
#   'product',
#   'your',
#   'customer',
#   'service',
#   'says',
#   'may',
#   'be',
#   'the',
#   'awb',
#   'no',
#   'is',
#   'wrong'],
#  ['i',
#   'dont',
#   'care',
#   'about',
#   'that',
#   'i',
#   'want',
#   'my',
#   'product',
#   'i',
#   'wish',
#   'i',
#   'had',
#   'not',
#   'opted',
#   'ebaybut',
#   'in',
#   'future',
#   'i',
#   'am',
#   'not',
#   'going',
#   'to',
#   'choose',
#   'ebay',
#   'because',
#   'its',
#   'the',
#   'worst'],
#  ['the',
#   'seller',
#   'should',
#   'have',
#   'delivered',
#   'it',
#   'by',
#   'then',
#   'but',
#   'as',
#   'you',
#   'dont',
#   'have',
#   'it',
#   'just',
#   'see',
#   'if',
#   'the',
#   'seller',
#   'cant',
#   'help',
#   'd'],
#  ['i',
#   'havent',
#   'received',
#   'it',
#   'as',
#   'of',
#   'yet',
#   'and',
#   'i',
#   'have',
#   'a',
#   'contract',
#   'with',
#   'you',
#   'for',
#   'the',
#   'delivery',
#   'of',
#   'product',
#   'not',
#   'with',
#   'seller'],
#  ['so',
#   'instead',
#   'of',
#   'telling',
#   'me',
#   'to',
#   'contact',
#   'the',
#   'seller',
#   'you',
#   'guys',
#   'should',
#   'contact',
#   'the',
#   'seller'],
#  ['the',
#   'contract',
#   'is',
#   'between',
#   'you',
#   'and',
#   'the',
#   'seller',
#   'they',
#   'shipped',
#   'it',
#   'but',
#   'we',
#   'protect',
#   'you',
#   'if',
#   'you',
#   'didnt',
#   'get',
#   'it',
#   'if',
#   'you',
#   'open',
#   'a',
#   'case',
#   'd'],
#  ['i',
#   'havent',
#   'received',
#   'anything',
#   'as',
#   'of',
#   'yet',
#   'ill',
#   'contact',
#   'seller',
#   'tomorrow',
#   'morning',
#   'but',
#   'your',
#   'service',
#   'is',
#   'pathetic'],
#  ['did',
#   'you',
#   'view',
#   'our',
#   'link',
#   'we',
#   'can',
#   'give',
#   'a',
#   'refund',
#   'if',
#   'you',
#   'dont',
#   'get',
#   'it',
#   'just',
#   'look',
#   'at',
#   'our',
#   'guarantee',
#   'for',
#   'steps',
#   'on',
#   'activating',
#   'it',
#   'd'],
#  ['i',
#   'would',
#   'appreciate',
#   'that',
#   'i',
#   'got',
#   'the',
#   'refund',
#   'of',
#   'my',
#   'previous',
#   'damaged',
#   'product',
#   'from',
#   'ebay',
#   'but',
#   'where',
#   'are',
#   'the',
#   'timelines',
#   'for',
#   'delivery'],
#  ['the',
#   'email',
#   'address',
#   'associated',
#   'with',
#   'my',
#   'account',
#   'is',
#   'email'],
#  ['im',
#   'not',
#   'looking',
#   'for',
#   'the',
#   'refund',
#   'just',
#   'check',
#   'my',
#   'account',
#   'and',
#   'you',
#   'would',
#   'yourself',
#   'condemn',
#   'your',
#   'service',
#   'and',
#   'worst',
#   'packing'],
#  ['and',
#   'i',
#   'havent',
#   'received',
#   'it',
#   'yet',
#   'so',
#   'in',
#   'layman',
#   'terms',
#   'you',
#   'can',
#   'say',
#   'im',
#   'waiting',
#   'for',
#   'it',
#   'from',
#   '9th',
#   'of',
#   'oct',
#   'how',
#   'much',
#   'time',
#   'can',
#   'i',
#   'wait'],
#  ['and',
#   'so',
#   'you',
#   'have',
#   'provided',
#   'me',
#   'the',
#   'refund',
#   'for',
#   'that',
#   'but',
#   'as',
#   'i',
#   'was',
#   'mad',
#   'about',
#   'this',
#   'product',
#   'so',
#   'i',
#   'ordered',
#   'the',
#   'same',
#   'product',
#   'on',
#   '21st'],
#  ['i',
#   'am',
#   'looking',
#   'for',
#   'the',
#   'product',
#   'let',
#   'me',
#   'tell',
#   'you',
#   'something',
#   'i',
#   'bought',
#   'a',
#   'similar',
#   'product',
#   'on',
#   '9th',
#   'of',
#   'this',
#   'month',
#   'but',
#   'that',
#   'was',
#   'damaged'],
#  ['if',
#   'you',
#   'still',
#   'cant',
#   'see',
#   'this',
#   'please',
#   'dm',
#   'us',
#   'your',
#   'full',
#   'name',
#   'zip',
#   'code',
#   'amp',
#   'item',
#   'number',
#   'amp',
#   'well',
#   'advise',
#   'on',
#   'this',
#   'date',
#   'for',
#   'you',
#   '22ml'],
#  ['and',
#   'check',
#   'with',
#   'your',
#   'team',
#   'or',
#   'else',
#   'keep',
#   'my',
#   'fucking',
#   'money',
#   'as',
#   'you',
#   'guys',
#   'have',
#   'stressed',
#   'me',
#   'out'],
#  ['kindly',
#   'check',
#   'the',
#   'above',
#   'message',
#   'and',
#   'do',
#   'the',
#   'needful',
#   'for',
#   'your',
#   'worst',
#   'service'],
#  ['thank',
#   'you',
#   'for',
#   'your',
#   'reply',
#   'the',
#   'estimate',
#   'delivery',
#   'date',
#   'for',
#   'this',
#   'order',
#   'will',
#   'be',
#   'available',
#   'to',
#   'view',
#   'in',
#   'your',
#   '‘purchase',
#   'history’12'],
#  ['estimated',
#   'delivery',
#   'wed',
#   '25',
#   'oct',
#   'fri',
#   '27',
#   'oct',
#   'you',
#   'have',
#   'paid',
#   'using',
#   'paisapay',
#   'on',
#   '211017',
#   'but',
#   'i',
#   'havent',
#   'received',
#   'it',
#   'yet',
#   'on',
#   '11117'],
#  ['you',
#   'can',
#   'always',
#   'open',
#   'a',
#   'claim',
#   'to',
#   'get',
#   'the',
#   'ball',
#   'rolling',
#   'on',
#   'that',
#   'coverage',
#   'bb'],
#  ['i',
#   'did',
#   'that',
#   'they',
#   'closed',
#   'my',
#   'case',
#   'have',
#   'i',
#   'lost',
#   '£120',
#   'pounds',
#   'now',
#   'because',
#   'of',
#   'ebay',
#   'theft',
#   'and',
#   'ebay',
#   'does',
#   'not',
#   'care'],
#  ['well',
#   'i',
#   'would',
#   'be',
#   'more',
#   'than',
#   'happy',
#   'to',
#   'take',
#   'a',
#   'look',
#   'at',
#   'that',
#   'claim',
#   'for',
#   'you',
#   'could',
#   'you',
#   'dm',
#   'us',
#   'with',
#   'more',
#   'details',
#   'please',
#   'bb'],
#  ['the',
#   'delivery',
#   'company',
#   'is',
#   'saying',
#   'they',
#   'delivered',
#   'it',
#   'to',
#   'my',
#   'street',
#   'wont',
#   'give',
#   'address',
#   'the',
#   'seller',
#   'is',
#   'saying',
#   'she',
#   'has',
#   'proof',
#   'but',
#   'no',
#   'one',
#   'will',
#   'show',
#   'me'],
#  ['hey',
#   'james',
#   'could',
#   'you',
#   'send',
#   'us',
#   'a',
#   'dm',
#   'with',
#   'all',
#   'the',
#   'information',
#   'so',
#   'we',
#   'can',
#   'look',
#   'into',
#   'that',
#   'for',
#   'you',
#   'bb'],
#  ['what',
#   'option',
#   'do',
#   'i',
#   'have',
#   'if',
#   'i',
#   'bought',
#   'something',
#   'on',
#   'ebay',
#   'and',
#   'wasnt',
#   'delivered',
#   'and',
#   'ebay',
#   'closed',
#   'my',
#   'claim',
#   'to',
#   'get',
#   'the',
#   'money',
#   'back'],
#  ['on',
#   'a',
#   'desktop',
#   'go',
#   'to',
#   'item',
#   'page',
#   'view',
#   'item',
#   'gt',
#   'manage',
#   'offers',
#   'gt',
#   'change',
#   'offer',
#   'settings',
#   'you',
#   'can',
#   'get',
#   'that',
#   'going',
#   'here',
#   'cc'],
#  ['how',
#   'do',
#   'i',
#   'setup',
#   'automatic',
#   'declines',
#   'its',
#   'not',
#   'listed',
#   'in',
#   'your',
#   'help',
#   'centre',
#   'and',
#   'i’m',
#   'struggling',
#   'to',
#   'find',
#   'the',
#   'settings'],
#  ['this',
#   'is',
#   'to',
#   'help',
#   'sell',
#   'your',
#   'items',
#   'be',
#   'sure',
#   'to',
#   'set',
#   'up',
#   'automatic',
#   'decline',
#   'in',
#   'your',
#   'settings',
#   'so',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'see',
#   'low',
#   'offers',
#   'cc'],
#  ['can',
#   'you',
#   'remove',
#   'the',
#   'best',
#   'offer',
#   'facility',
#   'from',
#   'buy',
#   'it',
#   'now',
#   'items',
#   'i',
#   'am',
#   'selling',
#   'items',
#   'that',
#   'i',
#   'do',
#   'not',
#   'wish',
#   'to',
#   'offer',
#   '‘best',
#   'offer’'],
#  ['cancel',
#   'dropbox',
#   'business',
#   'hope',
#   'this',
#   'helps',
#   'take',
#   'care',
#   'of',
#   'things',
#   'for',
#   'you',
#   '22'],
#  ['how',
#   'can',
#   'i',
#   'change',
#   'my',
#   'work',
#   'dropbox',
#   'account',
#   'back',
#   'to',
#   'a',
#   'personal',
#   'account',
#   'i',
#   'tested',
#   'the',
#   'trial',
#   'version',
#   'now',
#   'i',
#   'want',
#   'my',
#   'account',
#   'to',
#   'be',
#   'personal',
#   'again'],
#  ['we’re',
#   'excited',
#   'to',
#   'announce',
#   'the',
#   'university',
#   'of',
#   'cambridge',
#   'is',
#   'using',
#   'dropbox',
#   'business',
#   'to',
#   'power',
#   'collaboration'],
#  ['hey',
#   'justin',
#   'apologies',
#   'for',
#   'the',
#   'delay',
#   'are',
#   'you',
#   'still',
#   'unable',
#   'to',
#   'access',
#   'the',
#   'ebook',
#   'let',
#   'us',
#   'know',
#   'thanks'],
#  ['fyi',
#   'was',
#   'on',
#   'your',
#   'solutionsmarketing',
#   'of',
#   'db',
#   'business',
#   'and',
#   'noticed',
#   'the',
#   'read',
#   'the',
#   'ebook',
#   'link',
#   'is',
#   'broken'],
#  ['we',
#   'understand',
#   'and',
#   'we’ve',
#   'added',
#   'your',
#   'comments',
#   'to',
#   'your',
#   'suggestion',
#   'cheers'],
#  ['please',
#   'do',
#   '“as',
#   'a',
#   'user',
#   'i',
#   'would',
#   'like',
#   'to',
#   'hide',
#   'irrelevant',
#   'or',
#   'old',
#   'contacts',
#   'from',
#   'suggestions',
#   'in',
#   'order',
#   'to',
#   'make',
#   'room',
#   'for',
#   'relevant',
#   'ones”'],
#  ['hi',
#   'there',
#   'currently',
#   'it',
#   'isn’t',
#   'possible',
#   'to',
#   'hide',
#   'the',
#   'suggestion',
#   'list',
#   'however',
#   'we',
#   'can',
#   'certainly',
#   'forward',
#   'this',
#   'request',
#   'to',
#   'our',
#   'dev',
#   'team'],
#  ['how',
#   'do',
#   'i',
#   'remove',
#   'the',
#   'suggested',
#   'contacts',
#   'in',
#   'invite',
#   'people',
#   'to',
#   'paper',
#   'column',
#   'i',
#   'dont',
#   'have',
#   'any',
#   'third',
#   'party',
#   'contacts',
#   'connected'],
#  ['hey', 'james', 'when', 'did', 'you', 'fly', 'e'],
#  ['can',
#   'you',
#   'please',
#   'update',
#   'my',
#   'tier',
#   'points',
#   'on',
#   'my',
#   'account',
#   'thanks'],
#  ['sorry', 'to', 'hear', 'this', 'process', 'was', 'so', 'frustrating', 'n'],
#  ['3',
#   'times',
#   'over',
#   'an',
#   'hour',
#   'on',
#   'the',
#   'phone',
#   'let’s',
#   'just',
#   'hope',
#   'everything',
#   'is',
#   'correct',
#   'now',
#   'i’d',
#   'hate',
#   'for',
#   'something',
#   'to',
#   'be',
#   'wrong',
#   'for',
#   'a',
#   'special',
#   'occasion'],
#  ['have',
#   'you',
#   'spoken',
#   'to',
#   'our',
#   'team',
#   'on',
#   'the',
#   'phone',
#   'about',
#   'this',
#   'what',
#   'were',
#   'you',
#   'advised',
#   'h'],
#  ['3rd',
#   'call',
#   'to',
#   'hoping',
#   'everything',
#   'is',
#   'sorted',
#   'booked',
#   'flights',
#   'for',
#   '4',
#   'guys',
#   'and',
#   '2',
#   'peoples',
#   'details',
#   'were',
#   'incorrect',
#   'should',
#   'i',
#   'be',
#   'worried'],
#  ['you',
#   'can',
#   'send',
#   'us',
#   'a',
#   'message',
#   'by',
#   'clicking',
#   'the',
#   'link',
#   'below',
#   'cr'],
#  ['refuses',
#   'to',
#   'provide',
#   'me',
#   'with',
#   'a',
#   'copy',
#   'of',
#   'my',
#   'contract',
#   'even',
#   'though',
#   'they’re',
#   'quoting',
#   'it',
#   'to',
#   'justify',
#   'stealing',
#   '800',
#   'from',
#   'me'],
#  ['hello',
#   'wed',
#   'like',
#   'to',
#   'know',
#   'more',
#   'about',
#   'your',
#   'twitter',
#   'post',
#   'please',
#   'send',
#   'us',
#   'additional',
#   'details',
#   'about',
#   'your',
#   'concerns',
#   'thank',
#   'you',
#   'cr'],
#  ['thank',
#   'you',
#   'for',
#   'taking',
#   'the',
#   'time',
#   'to',
#   'speak',
#   'with',
#   'us',
#   'today',
#   'we',
#   'appreciate',
#   'the',
#   'opportunity',
#   'to',
#   'help',
#   'mg'],
#  ['thanks'],
#  ['thank',
#   'you',
#   'for',
#   'your',
#   'patience',
#   'well',
#   'call',
#   'you',
#   'shortly',
#   'mg'],
#  ['i',
#   'made',
#   'another',
#   'try',
#   'to',
#   'call',
#   'you',
#   'and',
#   'reached',
#   'your',
#   'voicemail',
#   'please',
#   'return',
#   'my',
#   'call',
#   'at',
#   'the',
#   'given',
#   'if',
#   'you',
#   'still',
#   'need',
#   'help',
#   'kl'],
#  ['anytime', 'after', '12noon', 'today', 'or', 'anytime', 'tomorrow'],
#  ['we’re',
#   'here',
#   'from',
#   '800',
#   'am900',
#   'pm',
#   'et',
#   'mondayfriday',
#   'and',
#   '1100',
#   'am800pm',
#   'et',
#   'saturday',
#   'when',
#   'is',
#   'the',
#   'best',
#   'time',
#   'to',
#   'reach',
#   'you',
#   'ra'],
#  ...]

# %%
text=data['text']

# %%
#Find the top frequency words from the dataset (done previously in the Ipynb file)
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(stop_words='english', lowercase=True, max_features=15)
fit_transform= cv.fit_transform(text)
features = cv.get_feature_names_out()
features
top_words = list(features)
top_words
# Out:
# ['account',
#  'dm',
#  'email',
#  'help',
#  'hi',
#  'im',
#  'just',
#  'know',
#  'like',
#  'look',
#  'number',
#  'send',
#  'service',
#  'sorry',
#  'thanks']

# %%
import gensim.downloader as api

# Download and load the pre-trained GloVe model
glove_model = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
glove_model.save("glove_model.bin")

# %%
#Create and save the word2vec and Fasttext model to google collab itself

from gensim.models import Word2Vec, KeyedVectors, FastText
word2vec_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, sg=0)
word2vec_model.save("word2vec.model")

# Train FastText model
fasttext_model = FastText(sentences, vector_size=100, window=5, min_count=1, sg=0)
fasttext_model.save("fasttext.model")

# %%
#Load the models saved
word2vec_model = Word2Vec.load("word2vec.model")
fasttext_model = FastText.load("fasttext.model")

# %%
#Search for similar words using the models that we trained to the ones that we got using count vectorizer (top 15)
similar_words = {}
for word in top_words:
    similar_words[word] = {
        "Word2Vec": word2vec_model.wv.most_similar(word),
        "FastText": fasttext_model.wv.most_similar(word),
        "Glove_model": glove_model.most_similar('word', topn=5)
    }

# %%
for word, similar in similar_words.items():   #display them
    print(f"Top similar words for '{word}':")
    print("Word2Vec:", similar["Word2Vec"])
    print("FastText:", similar["FastText"])
    #print("Glove_Model",similar["Glove_model"])
    print("\n")

#From the below given words we realise that the most freq and similar words are related to account, email, number, help, service, assisstance etc
# Out:
# Top similar words for 'account':
# Word2Vec: [('booking', 0.8616283535957336), ('phone', 0.8609009385108948), ('order', 0.8507465124130249), ('name', 0.8491856455802917), ('email', 0.8430359959602356), ('address', 0.838095486164093), ('card', 0.8355706334114075), ('full', 0.83241868019104), ('acct', 0.8318496346473694), ('number', 0.8297367691993713)]
# FastText: [('“account', 0.9992746710777283), ('accounti', 0.9955956339836121), ('myaccount', 0.9955276250839233), ('accountsq', 0.9945540428161621), ('accountshubz', 0.9944950342178345), ('accountit', 0.9910048246383667), ('accountsean', 0.9908014535903931), ('accounts', 0.9885589480400085), ('account’s', 0.9878804683685303), ('accountsee', 0.9875584840774536)]
#
#
# Top similar words for 'dm':
# Word2Vec: [('send', 0.8738312721252441), ('gamertag', 0.8673363327980042), ('postcode', 0.8499742746353149), ('message', 0.8447126746177673), ('contact', 0.8258100152015686), ('shoot', 0.8236198425292969), ('lexie', 0.8214563131332397), ('✉', 0.817937970161438), ('dming', 0.814066469669342), ('concerns', 0.8134627342224121)]
# FastText: [('ddm', 0.9995154738426208), ('cydm', 0.9989535212516785), ('dmjm', 0.9979702234268188), ('dmdn', 0.996195912361145), ('dmjv', 0.9895312190055847), ('dmd', 0.9864431023597717), ('dm’d', 0.983604907989502), ('dmpm', 0.9761315584182739), ('dmgt', 0.9641275405883789), ('สามารถdm', 0.9537066221237183)]
#
#
# Top similar words for 'email':
# Word2Vec: [('correspondence', 0.8844524025917053), ('full', 0.847840428352356), ('account', 0.8430360555648804), ('username', 0.8378635048866272), ('request', 0.833991289138794), ('accounts', 0.8333947658538818), ('number', 0.833177924156189), ('name', 0.8303377628326416), ('confirmation', 0.8238588571548462), ('reply', 0.8218311667442322)]
# FastText: [('email12hn', 0.9981510043144226), ('emaildm', 0.9957298636436462), ('emailso2', 0.9949602484703064), ('smsemail', 0.9939228296279907), ('emai', 0.9936607480049133), ('emailgtgtgt', 0.9886306524276733), ('idemail', 0.9880774021148682), ('gmail', 0.9872139692306519), ('emails', 0.9841355681419373), ('lemail', 0.9832862615585327)]
#
#
# Top similar words for 'help':
# Word2Vec: [('talk', 0.8095622062683105), ('speak', 0.8079434037208557), ('continue', 0.806562602519989), ('assist', 0.8006436824798584), ('ask', 0.7965089678764343), ('proceed', 0.7859978079795837), ('tweet', 0.7789949774742126), ('comprehend', 0.766964852809906), ('see', 0.7610872387886047), ('write', 0.7605156898498535)]
# FastText: [('ihelp', 0.9932518601417542), ('ljhelp', 0.9930551648139954), ('ehelp', 0.9927964210510254), ('helpz', 0.9912810921669006), ('helpnm', 0.9910017251968384), ('helpcn', 0.9909875392913818), ('helpjv', 0.9908517599105835), ('helpu', 0.9908218383789062), ('helpdd', 0.9902690052986145), ('help23ka', 0.9899526238441467)]
#
#
# Top similar words for 'hi':
# Word2Vec: [('hey', 0.9070117473602295), ('hello', 0.8821990489959717), ('comprehend', 0.7996452450752258), ('allison', 0.7916520833969116), ('jack', 0.7907302379608154), ('clarify', 0.7889936566352844), ('query', 0.7828772068023682), ('jmr', 0.7715924382209778), ('anthony', 0.7635203003883362), ('clare', 0.7628452777862549)]
# FastText: [('nhi', 0.9926581978797913), ('bhi', 0.9876703023910522), ('yudhi', 0.983356773853302), ('abhi', 0.9054529666900635), ('hiw', 0.9051807522773743), ('hii', 0.8654006719589233), ('rahi', 0.8604042530059814), ('hiwe', 0.8525664806365967), ('hiim', 0.8193433284759521), ('heyy', 0.8011653423309326)]
#
#
# Top similar words for 'im':
# Word2Vec: [('disappoint', 0.8208818435668945), ('sneha', 0.8202386498451233), ('am', 0.8150419592857361), ('i’m', 0.8090114593505859), ('tasmin', 0.8084855079650879), ('baruch', 0.8039988279342651), ('sherelle', 0.797660768032074), ('oops', 0.7972269058227539), ('were', 0.7798028588294983), ('val', 0.7779877185821533)]
# FastText: [('jim', 0.9816887974739075), ('“im', 0.9729353785514832), ('imsi', 0.901518702507019), ('hiim', 0.9003811478614807), ('imo', 0.8923372626304626), ('imma', 0.8490602970123291), ('ooh', 0.8490045070648193), ('rahim', 0.840806245803833), ('him', 0.8381790518760681), ('slim', 0.8372054696083069)]
#
#
# Top similar words for 'just':
# Word2Vec: [('yes', 0.8644309639930725), ('never', 0.86276775598526), ('cancel', 0.8483207821846008), ('proplem', 0.8420146107673645), ('told', 0.8400837182998657), ('actually', 0.8341257572174072), ('saying', 0.8328464031219482), ('even', 0.8321225643157959), ('because', 0.8314619660377502), ('faulty', 0.8289405107498169)]
# FastText: [('\u200djust', 0.9681894183158875), ('justbread', 0.9558181762695312), ('itjust', 0.9552577137947083), ('hijust', 0.9448197484016418), ('justin', 0.9356403946876526), ('ju', 0.9262464642524719), ('justine', 0.9141417741775513), ('pojust', 0.9125046133995056), ('justify', 0.91164630651474), ('never”', 0.9073863625526428)]
#
#
# Top similar words for 'know':
# Word2Vec: [('knowthank', 0.7706615924835205), ('futurepls', 0.7383544445037842), ('jessicabrenhaug', 0.7217439413070679), ('else', 0.7204715013504028), ('see', 0.7168250679969788), ('ask', 0.7156650424003601), ('nutty', 0.7032623887062073), ('courthouse', 0.6952369213104248), ('daddy', 0.6943802833557129), ('constituents', 0.6876547932624817)]
# FastText: [('knowi', 0.9956991672515869), ('knw', 0.9818876385688782), ('kn', 0.9815293550491333), ('knows', 0.9813898801803589), ('knowbut', 0.9767569303512573), ('known', 0.9767245650291443), ('knn', 0.9682427048683167), ('kno', 0.9667860865592957), ('knowsean', 0.9664781093597412), ('knock', 0.9254658818244934)]
#
#
# Top similar words for 'like':
# Word2Vec: [('love', 0.9046878814697266), ('recommend', 0.7674517631530762), ('happy', 0.756003201007843), ('prefer', 0.6913456320762634), ('rely', 0.6854172945022583), ('mind', 0.6721706986427307), ('smfbur', 0.6545238494873047), ('certainly', 0.6536328196525574), ('opportunity', 0.6485374569892883), ('need', 0.6480889916419983)]
# FastText: [('“mike', 0.9765005707740784), ('likefix', 0.9729098081588745), ('nike', 0.9627143740653992), ('bike', 0.9548870921134949), ('unlike', 0.9514755606651306), ('hike', 0.9507380127906799), ('likeaboss', 0.931297242641449), ('mke', 0.9004088044166565), ('mike', 0.8958626389503479), ('likely', 0.8861149549484253)]
#
#
# Top similar words for 'look':
# Word2Vec: [('dig', 0.8945020437240601), ('deeper', 0.8805159330368042), ('dive', 0.7877286672592163), ('moment', 0.7859269976615906), ('looked', 0.7801839113235474), ('walked', 0.7652311325073242), ('mattlegleiter', 0.7629794478416443), ('awry', 0.7610076665878296), ('earliest', 0.7583213448524475), ('pasted', 0.7509186267852783)]
# FastText: [('2look', 0.9989104866981506), ('loop', 0.9785576462745667), ('lookin', 0.9776958227157593), ('outlook', 0.9715203642845154), ('loo', 0.9682119488716125), ('çok', 0.967778205871582), ('lookout', 0.9638897180557251), ('loom', 0.9600569009780884), ('544ok', 0.9599414467811584), ('lool', 0.9541838765144348)]
#
#
# Top similar words for 'number':
# Word2Vec: [('name', 0.9310874938964844), ('full', 0.9038277864456177), ('address', 0.8998364210128784), ('confirmation', 0.8852126002311707), ('booking', 0.8815829753875732), ('nectar', 0.8790336847305298), ('associated', 0.8689616322517395), ('postcode', 0.8679190874099731), ('zip', 0.8562530279159546), ('namezipphoneaccount', 0.8391368985176086)]
# FastText: [('numbern', 0.9946579933166504), ('number0710652323', 0.9944391846656799), ('number0724682816', 0.9944051504135132), ('number09073332155', 0.994394838809967), ('numberiz', 0.9943500757217407), ('numberms', 0.9940221309661865), ('number18602102484', 0.9939332008361816), ('numberkw37nq', 0.9934456944465637), ('numberjamo', 0.9934033751487732), ('numbermy', 0.9918086528778076)]
#
#
# Top similar words for 'send':
# Word2Vec: [('shoot', 0.9148449897766113), ('dm', 0.8738312721252441), ('message', 0.8266203999519348), ('✉', 0.8109354376792908), ('direct', 0.8015913963317871), ('tweet', 0.8012324571609497), ('gamertag', 0.7935488224029541), ('callchat', 0.7928353548049927), ('drop', 0.7910844087600708), ('meet', 0.7819350361824036)]
# FastText: [('senha', 0.9653611779212952), ('sendo', 0.9639622569084167), ('sender”', 0.961070716381073), ('anwesend', 0.9603943228721619), ('sends', 0.9581506252288818), ('senyum', 0.9558903574943542), ('gravesend', 0.9336530566215515), ('senan', 0.9325480461120605), ('sender’s', 0.9323444962501526), ('sendung', 0.9309514164924622)]
#
#
# Top similar words for 'service':
# Word2Vec: [('care', 0.8272207975387573), ('services', 0.7956517338752747), ('relations', 0.7719938158988953), ('satisfaction', 0.736203670501709), ('demeanor', 0.7228416800498962), ('experience', 0.7193239331245422), ('worst', 0.7144437432289124), ('customer', 0.7088606953620911), ('9506896979', 0.7064738869667053), ('advisor', 0.7055568099021912)]
# FastText: [('ihgservice', 0.9974719882011414), ('service”', 0.9972847104072571), ('serviceba', 0.9970008134841919), ('serviceif', 0.9944136142730713), ('lipservice', 0.9935094714164734), ('servicesarc', 0.9931735396385193), ('“service”', 0.9907620549201965), ('badservice', 0.9876165986061096), ('services', 0.9869016408920288), ('servicedm', 0.9863881468772888)]
#
#
# Top similar words for 'sorry':
# Word2Vec: [('pleased', 0.8230316638946533), ('apologies', 0.8210942149162292), ('frustration', 0.8191394209861755), ('allison', 0.8141771554946899), ('afraid', 0.8021136522293091), ('apologize', 0.7890719771385193), ('glad', 0.7890046238899231), ('trouble', 0.7861769199371338), ('emma', 0.7858166098594666), ('awaiting', 0.7774737477302551)]
# FastText: [('sorrynotsorry', 0.9987857937812805), ('hsorry', 0.9974987506866455), ('sorry22corry', 0.9974738359451294), ('“sorry', 0.9973213076591492), ('sorryhulu', 0.9972532987594604), ('sorrryyy', 0.9928866624832153), ('lrry', 0.9879985451698303), ('33corry', 0.9841594696044922), ('sorryfor', 0.9767119288444519), ('22corry', 0.9748343229293823)]
#
#
# Top similar words for 'thanks':
# Word2Vec: [('thank', 0.8618820309638977), ('dms', 0.7735344171524048), ('mikerice', 0.763963520526886), ('km', 0.7503129243850708), ('olly', 0.7457019686698914), ('confirming', 0.7436395287513733), ('asda', 0.7402735948562622), ('vn', 0.7397595047950745), ('david', 0.737633466720581), ('tb', 0.7372012734413147)]
# FastText: [('thanksnothanks', 0.9962637424468994), ('thanksfloi', 0.9955615401268005), ('thanksi', 0.9952349662780762), ('thanksmi', 0.9951130747795105), ('thanksm', 0.9949442148208618), ('thanksp', 0.9947343468666077), ('thanksmn', 0.9945839643478394), ('thanksjc', 0.9942653775215149), ('thanksha', 0.9916964173316956), ('kthanks', 0.9881630539894104)]

# %% [markdown]
# ## Task 5:
# Analysis from Three Perspectives: Analyze the output from three perspectives:
# a) Context: Examine the context in which the words appear in the Twitter data.
# b) Product: Identify any product or service-specific information present in the dataset.
# c) Location: Determine whether there are geographic-specific details or references within the Twitter data.

# %%
#Examining the context in the dataset
context_sentences = []
for word in top_words:
    sentences = data[data['text'].str.contains(word, case=False)]['text'].tolist()
    context_sentences.extend(sentences)

# %%
context_sentences
#From the below results we can say that the context is more based on customer support for issues and concerns regardign various topics such as money, accounts etc
#Account assistance, billing and payment issues, technical suppport, security concerns etc
# Out:
# ['can you please send us a private message so that i can gain further details about your account',
#  'please send me a private message so that i can send you the link to access your account fr',
#  'whenever i contact customer support they tell me i have shortcode enabled on my account but i have never in the 4 years ive tried',
#  'the correct way to do it is via an ocs account takeover and email consent form it does not need to be done in a local office',
#  'the information pertaining to the account assumption is correct this does need to be done at a local outlet wit',
#  'what else can i provide they refuse to help me because they cannot validate the account',
#  'we would not be able to verify anything without authenticating your account jay',
#  'we can use the order number to locate the account but will need to do so in our secure one on one chat please follow and dm us hsb',
#  'nobody can find my account or number i walked out of a store with this ive explained that they can find my acct via my devices serial',
#  'help is here to assist you in recovering your account we recommend that you contact our answer desk team',
#  'i need assistance recovering 2 hotmail accounts i have filled the recovery forms but am told am not providing enough info',
#  'have you redeemed that on your account even tho it says beta code your pre order bonus are linked ko',
#  'can you please give me your gamertag platform youre playing on so i can pull up your account information cb',
#  'hi you can change your microsoft account email through the steps here if the email your son wants to change to is already associated with a microsoft account youll need to follow those steps to switch the email address on that account too zm',
#  'can i change me sons xbox live account to his hotmail account currently linked to my hotmail account',
#  'hi there please dm us you adobe id so that we may have a quick look at your account details tanuj',
#  'hi there we would like to help please dm us your accounts email and reservation code so we can further assist thank you',
#  'wed recommend keeping an eye out on your email that is associated with your account for further info ja',
#  'hi loreen you may check the passengers date of birth via airasia member account under manage booking thankssha',
#  'hi are you receiving an error message when trying to link the account',
#  'i am unable to affect your account via twitter for real time support phone or chat use this link ch',
#  'i want my amazon payments account closed dm me please',
#  'bought an echo show and it won’t recognize a single account in our household wtf guys',
#  'could you send us a dm with your accounts email address well take a look backstage ch',
#  'and send us a direct message with your account information so that i can see whats going on –xg',
#  'hm we havent had any reported errors lately have you tried accessing your rr account via a different browser ma',
#  'is down on the my account page',
#  'hi simon i’m sorry to hear this sounds like your account may have been compromised i strongly advise you to contact our security teams gt if you haven’t already done so to make sure you do to ensure your account is fully secured gr',
#  'youll be glad to know that if you have a spotify student account you can get hulu for free',
#  'i am a college student why can’t i still use my mom’sfamily account while i’m away at college',
#  'i can look into that for you can you please send me your account or phone number directly in a private message as',
#  'i apologize the number provided is not bringing up an account can you dm me your full address please jb',
#  'why am i still receiving a bill for oct when i disconnected by account on sept 20th pls advise amp reverse the charges',
#  'well refer this to our wireless colleagues since we handle fios and dsl accounts they will be in touch hsb',
#  'i set up a paypal account before i was 18 fair play my bad was wondering if i could shut down the account so i can restart it now im 18',
#  'sadly we cannot close this account until you are 18 but we can close this account once you are 18 and you can op',
#  'i am sorry to hear about this trouble with accessing your account please send me a dm and i can help you further ga',
#  'been locked out of my account for 2 hrs 2 different agents have “reset my account for me” amp still no dice as soon as they get off phone',
#  'my account is telling me to reset my password but i dont know my date of birth but i know my password for the account help',
#  'someone got to my account and changed the email',
#  'hey were gonna need to talk about all these pending charges that keep going through my account 5 days after the transaction was made im getting real irritated',
#  'hello this does not sound good can you dm the account name and complete service address we would like to help dan',
#  'hi fɍ1sꝁɇnsŧɇɨn please dm account info including street address so we can look into this greg',
#  'hello this does not sound good can you dm the account name and complete service address we would like to help dan',
#  'the email address associated with my account is email',
#  'im not looking for the refund just check my account and you would yourself condemn your service and worst packing',
#  'how can i change my work dropbox account back to a personal account i tested the trial version now i want my account to be personal again',
#  'can you please update my tier points on my account thanks',
#  'hello do you have any account related concerns that we can help with our social care team is here if you need us thanks cr',
#  'hey there dm us the email on your account please we can help',
#  'so sorry for the trouble please dm us your account email so we can look into this',
#  'please let us know if you have any questions just dm us your account number and any questions you may have lexie',
#  'hey corey even on the new account you made you can turn of the auto renew through the same link sk posted for you aj',
#  'you have to log in i dont remember the email address i used can you look up the account by my bank information',
#  'they sent me the email i sent you guys that said i wasnt gonna be charged he must have been able to look up my account a different way',
#  'i tried my phone number but i didnt have a mobile account i went through this for 2 hours on the phone with someone',
#  'im sorry to hear youre not able to access your account please use this link instead to contact us lh',
#  'i have tried it’s not allowing me to access my account to cancel my membership i haven’t even used prime in almost 3 months',
#  'so essentially still two separate accounts just sharing payment info i dont want my family to see my christmas shopping list',
#  'if i add another adult to my amazon household with their own account can they see my wishlistsphotosorder history',
#  'it’s not allowing me to update it to register my new amazon account i read i’d have to do so manually thx 4 response',
#  'no problem you may need to deregister the kindle from the old account you can see how here aj',
#  'please dm us with your account email address and phone number so we can look into this',
#  'hello let me look into that for you please dm your account information so we can research this further thank you dp',
#  'i just opened an account with xfinity and needed the modem will it be shipped to my house or do i have to pick it up',
#  'ive called 5 times no resolution bill for a house i dont live in still remains and you all give me the run around to cancel my account',
#  'and the phone number associated with your account so i can look into this issue further thanks kw',
#  'hi singh please send us a dm with your account email address and phone number so we can locate your account thanks for your patience',
#  'after contacting you concerning deactivation of my account it was reactivated but after 48 hrs it has been been deactivated please help',
#  'hey there wed like to look into this please dm us the phone number on your account so we can assist you further',
#  'please verify if this is referring your verizon account number and not your banking jay',
#  'trying to sign up for autopay your site tells me my checking account must be min 12 characters mine is 9 so',
#  'whenever i go to play my game it says im on my old psn account which i deleted of my system ive used that account like once before',
#  'thanks for the info make sure your psn account has its own local user',
#  'hi having issue with an old account no idea what the loginemail is for it but i know the id',
#  'hi there you can create a new account but take in count that the content cannot be transferred from one account to another',
#  'please wait until launch make sure you are on the main account that purchased and owns the content rk',
#  'hi there if an account is not following the code of conduct here 12 ja',
#  'hey if someone creates a second account so heshe can play worse people because they have a higher skill and don’t want to play those people is that considered cheating',
#  'i submitted an online request and expect a cancellation credit to my account as i would of had to pay thank you',
#  'any reason i’m trying to inform ur support staff that my debit card is being charged fraudulently from another uber account while i’m at work and no one seems to care',
#  'thats a big lie otherwise my account would be up and running stop lying ill make it public all the lies your guys have told me been told it would only take 48 hours been waiting 5 days',
#  'answer me why if i report another driver with a gun in hi vehicle my account gets put on hold',
#  'we definitely want to take a closer look however due to our policy terms and conditions we will need to discuss this with the account holder please message us with the email address associated with the account and well follow up with her directly via inapp support',
#  'i already messaged you her email address not sure what you mean with inapp support but do you realize you guys deactivated her account',
#  'my wife account got charged w 2 uber eats orders we never placed called help number and after 20 min hold all we were told had to email uber help seriously',
#  'due to our privacy policy were not able to address these concerns over social please have the account holder or the person youre writing in for contact us at so we can assist them further please let us know if you have any other questions',
#  'were unable to view any account information via twitter whats the current tracking shown here ag',
#  'im sorry for the frustration without giving personalaccount details could you tell us a bit more about whats going on dg',
#  'im sorry for the frustration without giving accountpersonal details can you please provide us with more info ac',
#  'legacy shared prime benefits account trying to join an amazon household of the prim account holder to share echo and set up voice profile',
#  'have you tried deleting the card from the account and readding it have you reached out to usps about these deliveries af',
#  'sorry for the poor experience without giving any account information could you tell us whats going on wed love top help mh',
#  'thats not good please dm full address and primary name on the account so we can take a look jj',
#  'hi while hardwired to your equipment are you able to sign into your account online at and perform a speed test so that we can analyze it from here renee',
#  'i need help with my account it gets disabled every time i try to login and its getting really frustrating',
#  'sorry about that you shouldn’t have received an emailnotification if you’re not eligible can you dm us your accounts email address or username nq',
#  'hey there helps here could you dm us your accounts email address and username well take a look backstage cg',
#  'hey pazcal could you send us a dm with your accounts email address well take a look backstage mj',
#  'hey guys i tried to update my payment method and add my aussie visa credit card but it tell me that the card is for a nonspotify country im trying to migrate my account from france to australia since i live here now and i cant do that unless i use an aussie card',
#  'hey the cavalrys here can you dm us your accounts username or email address well take a look under the hood js',
#  'im using my facebook account as a method to log in',
#  'hey could you dm us your account’s email address we’ll check this out backstage cg',
#  'can you dm us your accounts email address well check things out kc',
#  'hi there can you dm us your accounts email address or username well take a look backstage nq',
#  'hey there can you send us the spotify uri just rightclick the track gt share gt uri also what country is your spotify account set to ag',
#  'hey krystal i can look into your account can you dm me your account info please matt',
#  'sorry about the service issues please send us a dm with your account info so i can helpjv',
#  'here its 615787351 and just go ahead and close the account i am done with you i will call chase and cancel out my rr visa adios',
#  'thanks ben drink coupons will no longer be sent to you amp the account will close when theres been no earning activity for 24 months ma',
#  'i can authorize 5000 bonus skymiles be deposited into each of your skymiles accounts as a gesture for the inconvenience 22 tac',
#  'i truly apologize for the frustration this matter has caused please dm your service phone number or account numb',
#  'my account gotten took can yall get it the gamer tag is talibankelo508',
#  'hi again smart sync can be enabled on your business account using the steps here',
#  'hi again do you have two emails a work and personal account and are they linked are you able to login to your personal account first',
#  'hi when i follow the link dropbox asks me to log in with my biz account i want to apply it to my personal account',
#  'hi danaan what error are you getting when you redeem the key for your dropbox account did you have plus before with evh',
#  'i went into my branch and was told it was not possible to set up monthly electronic payment into a business account at bofa used keybank',
#  'just wanted to pay my shop rent to new landlord amazing had to use my key bank account to set up payments to the bank of america account',
#  'bank of america strikes out again they cannot set up a reoccurring electronic deposit from my account to a business account at their bank',
#  'pls send us your full namezipphoneaccount type so our social care team can help you cr',
#  'name muyiwa dele olatunde zip30093 phone 7703743799 account type checking amp savings',
#  'hi muyiwa thank you for speaking with us last night we will research your account and follow up with you again today thanks bc',
#  'hi wed like to know what happened pls send us additional details with your namezipphoneaccount type and well follow up cr',
#  'hello for safety reasons only the accounts parental guardian or the account user can contact us for account issues co',
#  'funny how i cant cancel my little brothers account or contact you about it hmm',
#  'unfortunately it said that my account was temporarily locked out of the system still',
#  'i’m trying to make changes on my account but it keeps telling me i’ve been temporary locked out i already called to confirm my card',
#  'i will be happy to look into your service issues please dm me your account info so i can help gr',
#  'i apologize that you think that if you happen to need assistance with your internet please do not hesitate to dm us your account information we are here to help dg',
#  'i apologize you are experiencing some speed issues could you please dm your full firstlast name full service address including the city state and zip code and the phone number listed on the account dg',
#  'im sorry your account is locked please reach out directly to us here so we can take a closer look tn',
#  'um my account was locked as soon as i tried to login on desktop i still haven’t received an email on how to get it unlocked',
#  'i need to change the language of my account to be able to get support which i dont have the time to do theres any other way to contact',
#  'i’m having trouble with my choice account please help',
#  'hi were here to help please dm us the email linked to your uber account so we can look into this for you',
#  'hi nico can you send us a dm with your accounts email address or username well take a look under the hood xf',
#  'hi i’ve got an issue where my account is like hijacked with an appdevice that i don’t even know called spotiamb 0211',
#  'nope a few states away actually the airbnb were in doesnt have espnews so we signed in with our verizon account to go to espn3 and watch doesnt allow us which i dont get since i know we have espnews back home',
#  'i cant watch the temple game because this tv in vermont doesnt have espn news and our verizon account doesnt have it either and i am not happy about this at all this is absolute crap',
#  'shadi i can help with the box trouble to get started please dm your phone or account number and full addresscp',
#  'hi gina i can help turn those troubles around send me a dm with your full name service address and phone number on the account bg',
#  'hi i would love to help please dm me the phone associated with the account amp the service address jules',
#  'can you please dm us your account info so we can assist with any connectivity issues frl',
#  'hello i will be glad to answer any questions you have about your account or you bill please send me a dm sts',
#  'hi can you dm me with your account name address telephone number and email ty andrew',
#  'is psn down can’t log into my account',
#  'just checking in are you still seeing this with your account tweet us any time for official xbox support ez',
#  'when something on your xbox account went wrong and it’s saying it’s having trouble downloading wwii',
#  'hello will you please dm us with your account number so we can better assist you wayne',
#  'hello david will you please dm us with your account number so we can better assist you wayne',
#  'hi lorenzo yes children are able to sign up for rapid reward accounts jb',
#  'in registering the website wants me to enter their email address i cant reuse the one associated with my account is there a solution besides having to make email addresses for 4 and 5 year olds',
#  'please know one email address can be associated with multiple accounts jb',
#  'no my earlier message was correct several families have the same address associated with multiple accounts jb',
#  'so what your suggestion is that at sign up i go with a different email address and then later on go and change that to the email address i want to have the same across the accounts is that correct',
#  'heidi your kind words warm our heart we always love having you onboard and we look forward to many more great flights together please dm your rapid rewards account number for a little surprise lc',
#  'hello there i saw your tweet do you need help with something specific pls let me know no account number nc',
#  'sorry to learn about this were you able to speak with a banker about your card if you still need assistance dm us the relevant details your name address and phone number for your protection dont mention account numbers sc',
#  'ill do my best to help andrew send us a dm with more details about what happened along with your full name address and phone number no account number he',
#  'click on the link provided to send us a dm please with more information about your experience as we value the chance to address your concern no account number he',
#  'without sharing account numbers please tell me what happened to cause you to feel this way marshall i can review your concern and do my best to help dc',
#  'id like to have a better understanding of your situation please dm us and share more info about what occurred no account number nc',
#  'i would like to have 100 on my account for free',
#  'tell us what happened so we can look into what we can do to help please dont mention account numbers sc',
#  'what happened to cause your frustration tell me more about your situation and ill do my best to address your concern pls send us a dm no account number nc',
#  'i saw your tweet and you appear to be frustrated samira please tell me what happened to cause you to feel this way no account number nc',
#  'please tell us more about what happened in a dm along with your full name address and phone number no account number he',
#  'hi julieta id like to review your concern please tell me more about what happened no account number rg',
#  'is there an sms outage i have been unable to log into my account due to 2fa text and unable to do text banking thanks',
#  'let me try to help please dm us your full name phone number address and type of account you have without mentioning any account number he',
#  'everytime i turn around i wells fargo taking money out my account i’m bout to stop turning around‼️',
#  'im sorry we cant access your account via twitter for assistance please reach us here wt',
#  'will i loose my account already tried help by link and by calling customer service',
#  'will i loose my accountive tried help from that link and yesterday by phone customer service and no one is able to solve this',
#  'already tried help by mail and still problem persist please close my account and dont want to be a customer anymore',
#  'no luck on receiving the code by text or call will i loose my account yesterday a phone representative tried to help already',
#  'im not receiving 2step code by text or call in my smartphone cant log in into my account already got help by phone with no luck',
#  'hmm can you dm us your accounts email address or username well take a look backstage km',
#  'hey lauren can you dm us your accounts email address or username well take a look ns',
#  'i cant log into my account as its saying my password is incorrect but its the same one ive used for years i updated my email address but its saying i dont have an account registered to that address',
#  'my executive club account has been hacked please pm me',
#  'were unaware of any issues indur did you manage to get through to us youd usually have a discount showing under bolt ons within your my o2 account can you please check this and let us know feel free to drop us a dm ✉',
#  'i placed an order on friday for £20 for 20gb with 3 months free sim only thru live chat when i look at my account it shows £33 per month and i can’t talk to anybody on live chat now is it down',
#  'i can help with any issues youre having would you please send us a dm with your account infojv',
#  'i can look into your service issues please dm me your account info and i will be happy to help gr',
#  'im truly sorry for the inconvenience we dont have access to your account via twitter wed like to help if we can please connect with us here so we can assist you mo',
#  'im sorry for the frustration wed love to help but are unable to access your amazon account via twitter you can view the latest tracking information for your order including if it has shipped here lr',
#  'wed like to help in any way we can juan ive enabled direct messaging without providing personal or account information please tell us a little more about whats going on fd',
#  'kindly reach out our support team here for more details on account closure mk',
#  'can you tell us when this information was submitted account specialists can take up to 2 business days to investigate an account when the information has been sent ez',
#  'did information get sent to our accounts specialists to look into when you contacted in do',
#  'someone keeps trying to buy playstation cards on my account having a hard time getting customer service',
#  'trying to place an order this happened before and deleting and rentering my address fixed it but now its across multiple prime accounts to the same address',
#  'hello let me do some research on the account to see what is causing this problem please dm for assistance thank you dp',
#  'my account has been temporarily suspended and i was wondering why but i have not been emailed yet',
#  'hi arvid once an account has been created the online id cant be changed more details here',
#  'hi there check the following article to receive further details about the process with banned accounts',
#  'is there a way to get a psn account unbanned',
#  'i cant believe theres no other account mgrs available',
#  'hi there i need some infos about opening a checking account at bofa for foreigners im gonna be in miami next week only for this and i really could use some help',
#  'you may visit a local financial center to open a checking account ag',
#  'hello gordon will you please dm us with your account number so we can better assist you wayne',
#  'if i uninstall and reinstall the game on my xbox one will my account progress still be there',
#  'hey callie can you dm us the email on your account so we can investigate this',
#  'why would charge more than my order to my account and then decline the purchase i hate that app it’s so glitchy',
#  'we are live here on twitter can you dm us with your account email',
#  'yes can you dm us the email on your account please',
#  'can you dm us with your account email so we can check this out for you',
#  'id be glad to test the line and help if i can if youll dm your account number stephanie mike',
#  'hello kevin will you please dm us with your account number so we can better assist you wayne',
#  'hello jeff will you please dm us with your account number so we can better assist you wayne',
#  'well help in any way we can was this on an email account',
#  'some accounts may create separate folders for your drafts if youre still having trouble please dm us here',
#  'we saw that you mentioned us jr do you have an account related concern or inquiry sp',
#  'please send us your full namezipphone account type so our social care team can call you sp',
#  'for security purposes and protection of your account we will not be able to communicate via email ct',
#  'first of all fuck you second what if we didn’t either way thankfully we found a friend got the account back but guess what',
#  'surprise problem now we can’t get the account back on the xbox supervisors response “don’t you have a friend nearby that you can ask”',
#  'how would deleting an account off a device that cant connect to internet to troubleshoot it work be brought back oh it cant',
#  'i want to see action is made in this line 09020564975 to stop deducting my accountit is one of reason to cease reaching',
#  'azcommunity hi im unable to activate my student account can you help me',
#  'hello johnny will you please dm us with your account number so we can better assist you wayne',
#  'i don’t know my account number',
#  'someone added a credit to my account so next time i won’t have to pay for them thank you',
#  'hey there could you send us a dm with your accounts email address or username well take a look backstage fr',
#  'how long does it take usually for account recovery to get back to you it’s been about a week now',
#  'thanks for asking jennifer your credits are found in your account settings gt payment methods gt your coupons dm us if we can help further',
#  'hi fazal wed like to see if we can help please click here to send account type amp country opened in no acctspins ty mc',
#  'having issues getting the website to load so i can login to my account are you experiencing tech problems',
#  'i apologize for the delayed response have your concerns been addressed if not i will need the account holders',
#  'how do i get in contact with someone higher about one of customer service reps deliberately messing up my accounts and lying her name is ann',
#  'hi there we are not able to see customers account information here on twitter please reach out to us by calling 8662161072 and keep us updated on the outcome sp',
#  'no need already sent the request to delete my account toomanysecondchances',
#  'hey there could you send us a dm with your accounts email address well take a look backstage fr',
#  'yall charged my account 8 times uhhh',
#  'i am truly sorry for the troubles and inconvenience please dm your account details and i will look into this for you rd',
#  'i am glad you have reached out we will work on fixing this please send us a dm with your account number ye',
#  'your love means the world to us dm us your rapid rewards account number so we can make your next flight even better mk',
#  'i apologize for any issues tyler please dm us your account number or phone number so we can assist you tz',
#  'i do apologize for the inconvenience and i will be happy to help can you dm me your account number jp',
#  'sorry our tech never came i can check the account if you could dm your address or acct ps',
#  'been having an issue for a couple hours now trying to signup and now access my new account help',
#  'im sorry to hear of any frustration if you have any problems with your account please send a dm id be happy to help in',
#  'the vendor account you entered is not associated with the item you are trying to open when i try to open books with new ade',
#  'i ran latest update on my macbook pro and in that apps attached to my creative cloud account also updated loosing photoshop subscription',
#  'i cant login because it says your account does not have the correct permission to access xbox live functionalityi have live',
#  'hi there have you checked if youre signed into the right account keep us posted',
#  'yes its my correct account for the first 30 minutes only 2 commercials after that 1 every song seems too many thanks',
#  'hi im sorry for the trouble with your recordings can you dm the name address and phone number on the accountsean',
#  'hello i can please send me your phone number and the primary name on the account will',
#  'i would be happy to look further into this for you if you would provide your full address and account associated phone number in a dm jw',
#  'please provide by dm the full address and account number and name associated with your account thanks qs',
#  'please provide by dm the full address and account number and name associated with your account thanks qs',
#  'please provide by dm the full address and account number and name associated with your account thanks qs',
#  'i can understand your frustration over the disruption can you please dm the name address ampphone number on the account mlr',
#  'i can use the name on account phone number and full address nc',
#  'if you do not wish to send us the info that is your choice i cannot guarantee a discount for providing us your account details nc',
#  'i don’t know my account number and i just called comcast and they said an agent couldn’t help me',
#  'please dm account information so i can help thank you nc',
#  'we would be happy to help please dm account details thanks nc',
#  'hello i can help with that starz issue can you dm us your account information pleaes zl',
#  'hi there i would love to provide you with my account to review my situation but need to have someone check the recorded calls 1st cont',
#  'hi there dm us your account email so we can help',
#  'hi there dm us your account email so we can look into this',
#  'hey there dont worry helps here can you dm us your accounts email address well take a look backstage mt',
#  'hey my account which i pay for has become unmoored from my facebook which im sure is what im registered with',
#  'hi there can you dm us your accounts email address or username and a screenshot of the error message well take a look backstage nq',
#  'hey we can help here on twitter could you send us a dm with your accounts email address well take a look backstage ch',
#  'thank you for the information please dm us your email address to your account to get a specialist to follow up were standing by to assist',
#  'hello alex my apologies for any frustrations or inconvenience if you’d like to dm your account details phone n',
#  'please dm your service phone number or account number so we can look into this further rr',
#  'hello jimmy my apologies for any frustrations or inconvenience if you’d like to dm your account details phone',
#  'hey if you’re premium you can connect your spotify account to the musixmatch mobile app to enjoy lyrics js',
#  'sorry to hear that you are having trouble with your services can you please followdm your account number as well as the full service address ss',
#  'i am owner of the account i have created this folder some time ago i realized that ive been cut out from it',
#  'hi i problem with one of folders on my account for some reason i cannot edit it see attached photo',
#  'i login with facebook email but i think my email account for spotify is my old one email that is now defunct what can i do',
#  'wed recommend deleting your last tweet as it contains sensitive account info you can dm it to us instead ny',
#  'were happy you reached out so we can find you the info you need if you forgot your apple id go to the apple id account page from here click forgot apple id or password then click look it up from here follow the on screen prompts',
#  'we suggest creating a temporary admin account and try to sign then try to check if you will encounter the same issue',
#  'were unable to view your account but wed like to help in realtime via phone or chat here nn',
#  'hi there items are not billed to you until they have shipped if you have been charged for the order already the refund will reflect on your account within 57 business days you can read more about it here rd',
#  'hey alex can you dm us your accounts email address or username well take a look backstage rh',
#  'cant access my account annoyed that i have to tweet to get tech support for a service i pay for',
#  'hmm thats odd could you dm us your accounts email address well take a look under the hood kb',
#  'thanks for that can you dm us your accounts email address and username well take a look backstage kl',
#  'i can look into service issues please dm me your account info so i can help gr',
#  'hello i can help you with that please dm so we can verify your account for assistance thank you dp',
#  'can you please dm us the account info so we can provide an accurate update frl',
#  'i would like to change my name on my account to my married name how can i do this email address not working',
#  'hello gary i will be more than happy to assist you please send me a dm with your account name and phone or account number sts',
#  'as a user but not owner on a business account the process of ordering a new phone has been extremely frustrating',
#  'please dm full address and primary name on the account so we can take a look jj',
#  'pls attention of glo amp ncc was called on illegal deduction of my account till now no soln',
#  'without posting account information could you provide us with a few details about the issue wed like to help wm',
#  'please send us a dm with your account email address and well connect',
#  'hey there can you dm us your accounts email address well take a look backstage rb',
#  'can you dm us your accounts email address well take a look backstage kc',
#  'hello let me do some research on the account to see what is causing this problem please dm for assistance thank you dp',
#  'i see that youve recently posted about your comcast services dm your account so i can look into this amp speak privately db',
#  'can you please dm us your account info so we can check the status of this for you frl',
#  'i don’t have words for how frustrated i am by the lack of professionalism accountability and ability to resolve the problem',
#  'we’d love to have you with us i know that each customer has a unique situation and we want to help in choosing the right account for you please see to learn more about the different types of accounts that may suit your banking needs pe',
#  'do good banks even exist anymore i was enquiring informations opening an account at chase idk why they said i have to show proof of income and keep a balance of 1500 in there like really rothschilds',
#  'again contact is ashley wisniewski 3128907112 she is an account holder',
#  'we regret to hear of your recent experience and we want to help we will reach out to you momentarily to address your account concerns',
#  'you can check for any outages based on your account here jay',
#  'im trying to create an account but i still havent received the verifying email no inbox no spam help',
#  'oh no which os are you running have you tried opening illustrator on a new user account on your computer wren',
#  'so i guess your twitter account isn’t anymore helpful to customers than email or your 800 terrible service',
#  'did something happen if so tell me about your experience no account numbers and ill do my best to help eb',
#  'i get your concern benish as this is a public platform we wouldnt be able to check your orderaccount related info 12sv',
#  'oh no without providing personalaccount information could you tell us more about whats going on dg',
#  'we can definitely take a closer look please send us a dm of the email address connected to your account so we can further assist',
#  'today dont works the sms code for registration new account',
#  'account number and the phone number associated with the account so i may better assist you thank you lo',
#  'hello i can further look into these x1 reboots for you can you please dm me the full name and address on the account adw',
#  'can you please dm us your account info so we can help with any connectivity issues frl',
#  'did you find my phone that i returned to brooklawn nj store that was stolen by an employee and credit account',
#  'i do apologize for the inconvenience and i will be happy to help can you dm me your account number jp',
#  'hello i am happy to look into this can you dm your account name and full address cs',
#  'i apologize for the inconvenience i can look into that for you can you please send me your account or phone num',
#  'hi im sorry to hear about this please send me a dm with your account email address country of residence thanks jmr',
#  'so someone hacks my account takes my money 3 weeks later countless emails hours on hold nothing has happened',
#  'just received a payment confirmation from my mum’s account to my email address massive breach of data protection',
#  'i am encountering problems when withdrawing money from my paypal account to the bank my paypal email assist',
#  'im about to close my account my debit card literally never works its declined everywhere and its embarrassing they 13',
#  'i have asked for bank account 2 to be my primary why on earth would transactions still come out of 1 this is a major flaw',
#  'there are many factors that contribute to the search rank and sales wed love to review your account dm us details y',
#  'please use link below to send your full namezipphoneaccount type and we’ll follow up with you mm',
#  'hello were here to help please let us know if theres something we can help on your account mm',
#  'please let us know if you have any account related concerns we can help with thanks cr',
#  'check out my account and know that i had a husband near death for a year five surgeries noempathy',
#  'lets take a look at this for you could you dm us your full address and the primary name on the account xavier',
#  'please dm your complete address and name on the account maria',
#  'kindly restore my number my account has had a balance greater than rs20 9850873091 as per your message of 61017see complaint',
#  'oh no dm us the email on your account so we can investigate',
#  'yes dm us with your account email',
#  'oh no im really sorry to hear about this i have went ahead and credited the cost of the item back to your doordash account',
#  'why doesnt blue light filter work on kids account on the fire kids edition',
#  'wed like to help have you noticed any unauthorized activity on your account vb',
#  'i am still waiting for a response in regards to my account being disabled is there a number i can call',
#  'hey there could you send us a dm with your accounts email address well take a look backstage fr',
#  'hi i cant log on to my premium account are there any problems at your end',
#  'and send us a direct message with your account information so that i can see whats going on –xg',
#  'i apologize for the issues with the channel please dm us your account number or phone number so we can assist you tz',
#  'i apologize for the service issues david please dm us your account number or phone number so we can assist you tz',
#  'thanks for the tweet well refer this to our wireless colleagues since we handle fios and dsl accounts hsb',
#  'have some accountability if i don’t want your service this month do you really think knocking on my door 5xday will do it next month',
#  'hello could you please dm with the phone number associated with your lyft account',
#  'hey there can you please dm us the phone number associated with your account so we can look into this for you',
#  'can you please open my account so i can transfer the money in there and close the account',
#  'can someone please help me with my account email 27824381483',
#  'im sorry wed love to help where we can please give us more details without sharing personal account information lm',
#  'me purchasing two items within 6 minutes is not enough for you to freeze my damn account please remove all additional protections from my account because they all suck',
#  'were unable to access accounts on twitter but wed like to look into it for you here li',
#  'im so sorry to hear this without revealing any personal account information will you provide us with more details lh',
#  'i get prompted for a system administrator password on a mbp macos but there is no system administrator account i’m aware of',
#  'here to assist please send us a dm of the email address connected to your account and more details so we can take a closer look',
#  'can you dm us the username or email address so we can pull up the account and take a closer look ju',
#  'my apologies crystal i am happy to look into this for you please followdm us your account information including the full address and phone number so that i may assist you jf',
#  'hulu we’re having trouble authorizing your account with spotify please contact spotify support to help resolve this issue',
#  'i knew you would ge back to me via social media you all have a refund you owe me amp ive been trying to solve my account issue w you all',
#  'ive located your account to protect your privacy please delete the tweet that contains your address mary',
#  'please try to download the fox now app and sign into your cox account to see if you can access it there greg',
#  'we dont want to lose you as a cox customer we can look into this for you please dm your account information brenda',
#  'do you have time to chat securely through our website so i can look at your account b',
#  'do you have access to your account online you can also call 8004301000 247 clarissa',
#  'i’ve gotten locked out of my personal account and i want to get back into it i need help',
#  'hi please can u delete this account i am being harassed x',
#  'this person has violated my personal privacy by publishing a home address she has two accounts amp',
#  'im afraid well not be able to take any action on your account once it is put on hold request you to wait for the email hd',
#  'as this is account related our specialist team are the best ones to assist you 23 sv',
#  'hi you should have received an email with an update over your account we will not be check this for you rw',
#  'got this message few hours back then hour later asked me if my account was working i said no then the blocked me',
#  'why do i have uber navigator help charges to my account canada unknowncharges irritated',
#  'has your service been disconnected i can check the account if you could dm your address or account number ps',
#  'address and account number so i can assist further with this issue thanks kw',
#  'hello i do apologize for the internet issues could you please dm us an account number or telephone number so we can assist you ba',
#  'thank you for the update we encourage you to be persistent and keep trying to recover your account using the recovery form',
#  'i cant reset my password and i cant talk to an agent as i need to log into my account please help',
#  'hi there we are here to help can you please dm us your email address we would be able to locate your account and assist you thank you',
#  'ive had a charge appear on my account in another state while i was sleeping what do i do to get my money back',
#  'hey there please dm us with the phone number associated with your account so we can look into this for you',
#  'old account thanks for keeping me away from money i appreciate taking 200 off my hands and being a huge waste of time',
#  'thanks for making me call 3 times telling me to make a new account then limiting the new account',
#  'twitter is a social media platform well not be able to access any of your accountorder details please share your 12 sh',
#  'your airline and ticketing process is a nightmare why would you assign me two seats separate from one another when i ordered both tickets at the same time on the same account in the same order how does that make sense youre a greedy unethical company',
#  'hi there can you dm us your accounts email address or username well take a look backstage nq',
#  'i need help with my account i keep getting charged for an account that is on the free subscription but was once premium',
#  'and the phone number associated with your account so i can look into your concerns thanks kw',
#  'its not an individual account problem people around me are experiencing same issue im just letting u guys know lte is slowed to a crawl',
#  'hi whet can i find put the date an add on was added to my account i didnt add it but want to find out who did',
#  'i do apologize for the inconvenience and i will be happy to help can you dm me your account number jp',
#  'i do apologize for the inconvenience and i will be happy to help can you dm me your account number jp',
#  'i can’t access my account number because im paperless and can’t get on the internet to access it',
#  'sorry to hear that please try activating the system as primary under both accounts more details',
#  'cant you only have one primary account per console',
#  'hi there you can activate the system under this 2 accounts and set it as the primary device under each account',
#  'i activated both as primary and the other account still cant play it',
#  'still isnt letting the other account play',
#  'where are you located which country did you select to setup your account please provide us more details',
#  'north america ny more specifically both accounts were also set up in ny',
#  'i bought fortnite on the primary account now my sister wants to play it but cant play it on her account',
#  'this is only 200 coupon i had a mailer which gave 300 for checking account',
#  '12 if you open a chase premiere plus checking account you may get 300 after meeting the requirements please click',
#  'my coupon was for total checking account and coupon value 300',
#  'was looking to avail my coupon for 300 for opening chase account but the bank was ill staffed and my account opening postponed to tomorrow my coupon expires today plz help',
#  'hello can you dm us with the account name and service address we would like to help with this issue dan',
#  'hello this does not sound good can you dm the account name and complete service address we would like to help dan',
#  'hello this does not sound good can you dm the account name and complete service address we would like to help dan',
#  'how long should it take for miles to credit to my account from flights on virgin america been 35 weeks now',
#  'wed be happy to help please dm us the email address for your account',
#  'i apologize for the lack of internet if youd like to dm with your account number i can take a look for you scott',
#  'can you dm us the phone number associated with your account so we can look into it',
#  'please dm us with the phone number associated with your account so we can look into this for you',
#  'hey jade can you please send us the phone number associated with your account so we can look into this for you',
#  'wtf man yall let some rando change my email to my account and now i cant log in fix it',
# ...
#  'not a fan of the new osytercard app logs in with existing account but doesnt list connected card still a few bugs need sorting',
#  'okay i can definitely do some diagnostics tests from my end would you mind sending a dm with your account info jw',
#  'i am sorry for the poor experience can you please dmpm the full service address and name on the account as we assist customers’ countrywide cd',
#  'im sorry to hear about the service issue i can certainly take a look please followdm the account information including the full address and phone number cl',
#  'give us a call at 8667898292 to establish an account or go to a sprint store fr',
#  'to continue our conversation can you please send a private message so that i can gain further details about your account',
#  'this added security on top of my security i put on my account makes no sense saying it’s cont',
#  'if there is something specific i can assist you with please feel free to send me your phone or account number in a private message as',
#  'i apologize if you are able to access please send the phone number associated with your account in a dm for further assistance az',
#  'i am happy to look into this can you dm your account name and full address cs',
#  'i apologize for any issues please dm us your account number or phone number so we can assist you tz',
#  'if you’d like to follow us amp dm your account details phone number and full address i’d be happy to check into this for you ap',
#  'hello jen my apologies for any frustrations or inconvenience if you’d like to dm your account details phone nu',
#  'not sure why you expect that to work and it doesnt just have to live with it til norton allows account holders to suppress useless info',
#  'yes but only till i log out but not relevant i want to remove all expired subscriptions from my norton account they have expired',
#  'neither im talking about the renewal reminder for an expired subscription that shows in my norton account every time i login',
#  'hello i have tried to top up credit on my number0724682816 my account was blocked please i need your assistance',
#  'im sorry that weve let you down without any personal or account information can you tell us what happened tr',
#  'pathetic service assistancehave not been able to book cab for more than a month due to technical error on my account 919619556066 and all i get is your ridiculous automated reply',
#  'response seems to be just change your password and there is no way anyone would know my account password concerning 250 of food',
#  'so is having your account hacked a thing then new to me woken by multiple ubereats delivery drivers across uscan',
#  'i am sorry for the poor experience can you please dmpm the full service address and name on the account as we assist customers’ countrywide cd',
#  'hi scott are you having an issue with your seller account have you been in touch with seller support for assistance ts',
#  'my apologies greg i am happy to look into this for you please followdm us your account information including the full address and phone number so that i may assist you jf',
#  'if there is something specific i can assist you with please feel free to send me your phone or account number in a private message as',
#  'hi kelly id be happy to look further into this for you please dm your account information so i can take a look ls',
#  'dear why can i not listen to an audiobook normal on the android app why does it only work on shuffle for non premium accounts sort of useless having the books available to those who dont subscribe',
#  'has nobody checked there online accounts i checked mine and mines been shipped i’ve got my tracking number and stuff',
#  'i don’t have an amazon account the parcel has been delivered to the wrong address',
#  'this could be a prime charge that you can cancel through your account km',
#  'have taken £80 out my account without my consent',
#  'please check my account i reinstalled d app today and its showing an outstanding of yesterday surprising plz resolve',
#  'hi i have 5 clubcards saved to my account but only use 1 of them now how can i remove the other 4 from my account',
#  'i have requested a loan on mshwari it has been confirmed but not available on my account 0700326949',
#  'i cant seem to log into flying club or my account to book a flight is there an issue at the moment or am i just unlucky',
#  'cant log in to my virgin club account mem no1034085975',
#  'you both have me fcked up right before the holidays i need some answers and some money back in my bank account barnesandnoble ups keepingpackageshostage happyholidays worstcustomerservice neveragain',
#  'i noticed your tweet willy is there something i can help you with please dont use account numbers in your reply hh',
#  '1000 was deducted f on my account balance yesterday i dial 12753',
#  'a thousand natural was deducted f on my account balance yesterday i dial 12753',
#  'still get this even when i am signed in to my account',
#  'hey walmart cut it out w the cute sweaters and cardigans my bank account cant',
#  'the extended prime subscription that came with the echo does not reflect on my account pls help',
#  'se hai già effettuato lordine su amazonit dovresti vedere la tracciabilità del pacco direttamente dal tuo account mz',
#  'i think its time to unlink my paytm account for because they cant differentiate the cancel request and just deduct the amount',
#  'send us a dm with more info about your account so we can look into it thanks for reaching out lisa naej',
#  'i accidentally left my data roaming on for 2 days in india but didnt use internetcan you check my account hasnt been charged',
#  'thanks gabby for security could you dm us the name of the account holder via the link dan',
#  'dayum 9 years with amp all ive ever been sent is fun reminders that my bill will be taken out on the 19th amp to check my online account if i want further info',
#  'please don’t provide account details as we consider them as personal info our twitter page is visible to public 22bs',
#  'dont make people fooldsunblcok my aocunt or refund my all money in my bank account',
#  'i cant get to this link bcoz it is saying to login amaozn aocuntbut my acount is on holdplz unhold my account',
#  'apologies for the hassle as the account is on hold you should have received an email from our specialist team hn',
#  'kindly reply to the email youve received from our account specialist team for further assistance on this issue 22 ri',
#  'please don’t provide account details as we consider them personal info our twitter page is visible to public 33bs',
#  'account please reach out here amp well forward to the concerned team to help you further 23 bs',
#  'ideally any account change will be followed by accounts team correspondence if you are holding an amazonin 13bs',
#  'i get you being upset pardeep however please know that the account specailst team is the best to handle this 12ms',
#  'i am trying to transfer a domain from my account to another domain registrar i tried multiple sending authorization code from but i didnt receive single email yet solve this asap',
#  'hey andre can you dm us your accounts username or email address well take a look under the hood rs',
#  'it is completely unacceptable to be on online chat for 1 hour 30 mins just to sort out a simple account issue',
#  'so i got charged twice for xbox live i paid with paypal but they charged my bank account too',
#  'i am sorry for your troublecan you please provided us the email address so we can refund you the money back to your account',
#  'lets take a look at this for you abigail when did you apply for your isa account with us jb',
#  'i have been waiting weeks for my isa account to be open and no one seems to be keeping me updated can you cancel my account',
#  'thats right heads together were our official charity last year which account do you like the look of lb',
#  'i do not have a lb account but i am interested in a savings account is this the company that was a part of the headstogether campaign',
#  'hi lets take a look what type of virgin money accounts do you hold lb',
#  'is there a way i can link my 18 student card to my tfl account it says my memorable date is wrong but i confirmed it with them today',
#  'without giving account specifics can you tell us a little more about the issue youre experiencing an',
#  'if you can send me your name address amp email by dm i will try a few fixes on your account mike 22',
#  'ya ive done that already and its still telling me i need to link my account',
#  'thanks dj that did allow me to play music now using spotify as if it was a bluetooth speaker but i was really hoping to link it for voice control etc could it be that my wife is the echo account owner i feel like that shouldnt have an effect tho',
#  'my echo keeps telling me that i need to link my premium spotify account to play music from there but i have already done that can you help',
#  'wed be happy to look into this please dm us the phone number or email address associated with your account',
#  'please help i have a buyer asking for paypal info over messages when account is linked feels like a scam what shall i do',
#  'i was told id receive an email to reset my password since my account was hacked and 5 phone calls later nothing',
#  'i cant log in to my account to even do that thats the issue i have zero access cause its been hacked',
#  '2 months later 5 phone calls speaking to an upper level manager and i still havent received access to my account cool guys',
#  'as were unable to view your account via twitterpls contact here so we can help you out km',
#  'hi the account specialists would require the information to be provided via fax tara s',
#  'have been following from 2 weeks to unhold my account',
#  'this is a screen shot of the email my account says the item is delivered but the post office is closed as i explained to the customer service person on the phone explain how ill get my parcel',
#  'we wouldnt have access to any account info from here what was advised when you reached out for support nv',
#  'i can dm you my info if you need to look at the account associated to see what options we have',
#  'hi uber im receving text confirmation message but i didnt use the app is somebody hacking my account',
#  'we believe that to finish the verifications on your account you need to upload an online id this link will help',
#  'we apologize for the delay lu we were unable to find an account using that email address was it the one you signed up with 12',
#  'were sorry to hear this can you dm us the phone number on your account',
#  'yes when the package is in transit the shipper is typically the only party that has access to changing the address if you have a ups my choice account you can see if the option is available online mm',
#  'your help pages dont reflect changes to the site eg change account settings no longer exists',
#  'kindly share your details using the link mentioned earlier as we wouldnt be able to access your account over twittergd',
#  'im so sorry for the trouble without including accountpersonal information could you tell us more about whats going on sd',
#  'many sellers are affected by this we cant get our money disbursed from amazon seller accounts its been going on for a week',
#  'i am not able to login my account 9599283689 showing access denied kindly help',
#  'still waiting for my account to be closed amp an email from uber teamits been more than 12hrs nowthats not good customer service at all',
#  'my uber account got deactivated for some unknown reason please help',
#  'we want to help but well need to speak with her directly we cannot speak with you regarding your mothers account aw',
#  '6am alert that my bank account is at 66666 tysm i worked hard for dis xx',
#  'for the security of your account please delete this message with your personal information rs',
#  'accepting donations chase bank 812670297 account number 083000137 bank routing number please do not be a thief you will be caught',
#  'thank you for reaching out to us we recommend reviewing your account online at or the mobile app rr',
#  'hi how long do i have to wait before i see money in my account for an item that i’ve sold',
#  'lets take a further look into this please send us a dm with your email and phone number linked to your account',
#  'how can i expedite getting my account reenabled',
#  'hey adelio can you please provide your account email so we can better connect we will follow up',
#  'hi can you tell me why i can add no credit cards or paypal account on my uber impossible to use the app',
#  'hello why the uber man started the pool and am not in the car and y’all done charge my account',
#  'its still listed on your aadvantage account is it not showing up on your reservation if not dm the number and your date of birth',
#  'my tsa pre info disappeared from my account any idea why',
#  'cant login to my flying club account and then when i call virgin the number they give on the website goes dead',
#  'if this is the first time you have transferred from amex it can take up to 10 days to show in your flying club account bm',
#  'amex transferred 18000 rewards yesterday when will they show up on my account please',
#  'please speak with customer service at 8005284800 247 we look forward to assisting you with your account',
#  'i signed into my rewards account 2night to take advantage of the hilton honors transfer bonus may i still take advantage of that',
#  'guys please deep this i was ranting about the shit service i received from and this fake amazon account posed as them and asked for my card details address etc then blocked me beware guys',
#  'yes same thing its not working im trying on both my account and as a guest it says both times that i do not have access',
#  'we want to help ashish please dm us the email and phone number linked to your account and we will follow up',
#  'happy to take a closer look at your inquiry ashish please dm us your account email and well follow up thanks',
#  'sorry for any delays please dm us the uber phone number currently on your account so we can better assist',
#  'mu account appears to have been disabled urgent please',
#  'hey could you send us a dm with your accounts email address or username well take a look ay',
#  'oh no are you able to login any error messaging the signin you use for your spotify account should be the same for hulu',
#  'wed really like to review your account and help with this please send us a dm to facilitate resolution sup ks',
#  'well like to review your account for the most cost effective offer please send us a direct message for further assistance ajs',
#  'we apologize for the issues you have experienced team will reach out to you to address your account concerns today',
#  'thanks so much for responding ive moved away from that address now so do you need the new address or my account details',
#  'hi share your account number for further assistance os',
#  '22 if you dont have an account already please see link to create one thanks mark',
#  'using my contactless my bank account indicates im paying individual fares for connecting bus and tube journeys how do i appeal',
#  '12 hi danny please sign into your contactless online account to contact us or call 0343 222 1234 for us to look into this',
#  'hi laura have you received any update from an account specialist about your account ts',
#  'if this francisco reyes guy even exists it’d be great to get my account back at this point has the worst customer service',
#  'hey this is the 2nd time ive seen a random 15 charge to my account from itunes on my card and i havent gotten anything',
#  'somebody trying to get into my account',
#  'you bloqueda my account no reason its not fare mi mail email',
#  'i stop my account in uber by the platform and the platform has no specific place and no specific number what is the reason',
#  'where is process stuck you have my card details uber account details just issue the reversals finish how many times say the same thing',
#  'unable to make payment for my premium account nothing wrong with my card as checked with the bank',
#  ...]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# Extract product or company names
product_names = []
for text in data['text']:
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ == 'PRODUCT':
            product_names.append(ent.text)

# %%
#From this we understand that the major products discussed here are about video games such as xbox
#alternatively there have been mentions about Scorpio and Nintendo switch too
product_names
# Out:
# ['xbox one',
#  'xbox',
#  'xbox one',
#  'xbox one',
#  'scorpio',
#  'tmt',
#  'xbox',
#  'xbox',
#  'xbox',
#  'xbox',
#  'xbox',
#  'xbox',
#  'xbox one',
#  'xbox',
#  'tengo volando con',
#  '737',
#  'xbox one',
#  'xbox one',
#  'ep17',
#  'xbox',
#  'xbox one',
#  'xbox one',
#  'xbox',
#  'xbox',
#  'ballin shawn',
#  'am60',
#  'xbox',
#  'max',
#  'xbox one',
#  '？ nintendo switchを購入したいんですが',
#  '404s',
#  'pero',
#  'xbox',
#  'xbox',
#  'quesadilla',
#  'xbox',
#  'xbox one',
#  'xbox',
#  'xbox',
#  'xbox one',
#  'ilfh6',
#  '⚾',
#  'chasus33',
#  'scorpio',
#  'xbox',
#  'xbox',
#  '630p',
#  'हैं',
#  '？',
#  '現在、そのandroidでメールが一切受信できなくなった、ということでよろしいしょうか',
#  'mw2r',
#  '？',
#  'xbox one',
#  'me25',
#  '240p',
#  'xbox',
#  'sg22',
#  'svuseason18',
#  'kaye',
#  'kaye',
#  'am12 pm',
#  'rs19',
#  '232',
#  '340',
#  '747',
#  'gqg43e',
#  'thro',
#  'rc18',
#  'the2',
#  'to23',
#  '747s',
#  '747',
#  'das so',
#  'das problem',
#  'us12au',
#  'बुकिंग',
#  '200s',
#  'diese',
#  'ba206',
#  'xbox',
#  'xbox',
#  'xbox',
#  'xbox',
#  'xbox one',
#  'xbox one',
#  'xbox',
#  'xbox',
#  '757',
#  'ak36',
#  '、、、',
#  '767',
#  'alexandria',
#  'your13',
#  'nuestro sac para',
#  '？ 穴から出ている手、、、、、カワイイですね ´艸｀ty',
#  '•',
#  '0722000000',
#  'rs1000',
#  '100n',
#  'sorry lauren km',
#  '747 gcivg',
#  'xbox one',
#  'das system das eigenständig',
#  'no7970336723',
#  'vs15',
#  'giorno',
#  'mashaallah',
#  'banamex llamo',
#  '905a',
#  '905a',
#  '735a',
#  '745a',
#  '0749',
#  'xbox one',
#  '787',
#  'indicated12',
#  '757',
#  'das sein',
#  'xbox',
#  'xbox one',
#  '100',
#  'vs66',
#  'xbox',
#  'a2',
#  'ak6114',
#  '915a',
#  'eu não entrar',
#  'gt30km',
#  '737',
#  'sg33',
#  '20000mah',
#  'para',
#  'resolution sup',
#  'das reklamieren können',
#  'ps plus',
#  'che amazon']

# %%
location_names = []
for text in data['text']:
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ == 'GPE':  # GPE stands for geopolitical entity
            location_names.append(ent.text)

# %%
location_names
# Out:
# ['mississippi',
#  'the retina imac',
#  'tanuj',
#  'airasia',
#  'airasia',
#  'narnia amazon',
#  'anna',
#  'germany',
#  'china',
#  'n’t',
#  'lexington',
#  'aeromexico',
#  'n’t',
#  'delhi',
#  'amsterdam',
#  'london',
#  'london',
#  'london',
#  'sacramento',
#  'burrito',
#  '✨',
#  'burrito',
#  'n’t',
#  'burrito',
#  'burrito',
#  'quochuy046',
#  'arizona',
#  'us',
#  'georgia',
#  'apps fuccin',
#  'germany',
#  'hurricane irma',
#  'san francisco',
#  'london',
#  'seattle',
#  'singh please',
#  'hai',
#  'singapore',
#  'noooooooooo',
#  'rechaza',
#  'tanuj',
#  'tanuj',
#  'tanuj',
#  'us',
#  'us',
#  'london',
#  'america',
#  '’s',
#  'pittsburgh',
#  'd7',
#  'canada',
#  'france',
#  'australia',
#  'n’t',
#  'lima',
#  'amsterdam',
#  'paris',
#  'birmingham',
#  'london',
#  'n’t',
#  'n’t',
#  'n’t',
#  'n’t',
#  'afc',
#  'bronx',
#  'us',
#  'london',
#  'uk',
#  'uk',
#  'uk',
#  'alaska',
#  'c’m',
#  'miami',
#  'charlotte',
#  'int’l',
#  'n’t',
#  'möchte',
#  'los detalles',
#  'germany',
#  'geneva',
#  'mexico city',
#  'washington',
#  'france',
#  'vermont',
#  'central jersey',
#  'kuwait',
#  'kuwait',
#  'kuwait',
#  'kuwait',
#  'kuwait',
#  'kuwait',
#  'kuwait',
#  'kuwait',
#  'kuwait',
#  'kuwait',
#  'mumbai',
#  'london',
#  'britain',
#  'burrito',
#  'n’t',
#  'us',
#  'ceri',
#  'rudyrobledo',
#  'netflix',
#  'n’t',
#  'london',
#  'atlanta',
#  'mexico',
#  'japan',
#  'jeffersonville',
#  'new york',
#  'kansas city',
#  'chicago',
#  'denver',
#  'denver',
#  'n’t',
#  '’s',
#  'la',
#  'el transportista',
#  'la entrega',
#  'new hampshire',
#  '122am',
#  'चोट्टे',
#  'uk',
#  'the west coast',
#  'kevinm',
#  'netflix',
#  'us',
#  'netflix',
#  'austin',
#  'aaahhh',
#  'washington',
#  'las',
#  'florida',
#  'iflyalaska',
#  'alaska',
#  'wallington',
#  '’s',
#  'miami',
#  'london',
#  'london',
#  'england',
#  'brazil',
#  'sou',
#  'london',
#  'tenia',
#  'qnd',
#  '’s',
#  'n’t',
#  'n’t',
#  'mexico',
#  'mexico',
#  'bahasa',
#  'oferta',
#  'muchos',
#  'panama',
#  'panama',
#  'london',
#  'london',
#  'arlington',
#  'florida',
#  'uk',
#  'uk',
#  'us',
#  'n’t',
#  'lagos nigeria',
#  'nigeria',
#  'us',
#  'argentina',
#  'argentina',
#  'netflix',
#  'tanto',
#  'blops3',
#  'n’t',
#  'n’t',
#  'costa mesa',
#  'houston',
#  'philadelphia',
#  'dallas',
#  'dubai',
#  'dubai',
#  'philadelphia',
#  'philadelphia',
#  'new york',
#  'naples',
#  'italy',
#  'pleasewe',
#  'missouri',
#  'orlando',
#  'texas',
#  'n’t',
#  'london',
#  'minneapolis',
#  'san jose',
#  'delhi',
#  'germany',
#  'london',
#  'liverpool',
#  'london',
#  'homebutton',
#  'queretaro mexico',
#  'london',
#  'la',
#  'india',
#  'india',
#  'india',
#  'india',
#  'chicago',
#  'charlotte',
#  'netflix',
#  'alaska',
#  'la',
#  'florida',
#  'lexington',
#  'florida',
#  'florida',
#  'alaska',
#  'dallas',
#  'washington',
#  'san francisco',
#  'burrito',
#  'else12',
#  'manhattan 6th',
#  'india',
#  'india',
#  'india',
#  'india',
#  'us',
#  'london',
#  'valeriep',
#  'burrito',
#  'burrito',
#  'n’t',
#  'london',
#  'iflyalaska',
#  'onda',
#  'uk',
#  'usa',
#  'uk',
#  'malaysia',
#  'tokyo',
#  'tokyo',
#  'london',
#  'manwhy',
#  'canada',
#  'burrito',
#  'india',
#  'manhattan',
#  'brooklyn',
#  'uk',
#  'india',
#  'north jersey',
#  'denver',
#  'bronx',
#  'n’t',
#  '♀',
#  '06111',
#  'us',
#  'us',
#  'delhi',
#  'mumbai',
#  'india',
#  'delhi',
#  'mumbai',
#  'los inconvenientes recomiendo',
#  'n’t',
#  'n’t',
#  'boston',
#  'kok',
#  'london',
#  '’s',
#  'america',
#  'newcastle',
#  'india',
#  'dublin',
#  'us',
#  'canada',
#  'n’t',
#  'kenya',
#  'vihiga county',
#  'puerto rico',
#  'puerto',
#  'netflix',
#  'hawaii',
#  'netflix',
#  'us',
#  'us',
#  'n’t',
#  'db',
#  'birmingham',
#  'london',
#  'afghanistan',
#  'airasia',
#  'north jersey',
#  'us',
#  'new orleans',
#  'oneonta',
#  'nacho',
#  'florida',
#  'jonesboro',
#  'montana',
#  'toledo',
#  'ohio',
#  'quesarito',
#  'mossbluff',
#  'louisiana',
#  'webb city',
#  'chicago',
#  'oklahoma city',
#  'united states',
#  'hsdvto',
#  'chicago',
#  'missouri',
#  'california',
#  'netflix',
#  'n’t',
#  'nett',
#  'deckung',
#  'kansas',
#  'hong kong',
#  'n’t',
#  'canada',
#  'おいいいいい！発売する三ヶ月前から予約注文で受け付けた品物くらい発売日にきっちり届けろよamazonさんw',
#  'detroit',
#  'washington',
#  'atlanta',
#  'los angeles',
#  'burrito',
#  'india',
#  'acaba de ser devuelto',
#  'semanas',
#  'us',
#  'burrito',
#  'paddington',
#  'n’t',
#  'alaska',
#  'n’t',
#  'accountshubz',
#  'ceri',
#  'tina',
#  'davenport iowa',
#  'utah',
#  'utah',
#  'amsterdam',
#  'bangkok',
#  'jordan',
#  'ohio',
#  'toledo',
#  'utah',
#  'myrtle beach',
#  'myrtle beach',
#  'nebraska',
#  'ceri',
#  'newcastle',
#  'london',
#  'chicago',
#  'nevada',
#  'denver',
#  'n’t',
#  'new jersey',
#  'rego park',
#  'indonesia',
#  'airasia',
#  'therewe',
#  'us',
#  'santa monica',
#  'ceri',
#  'ceri',
#  'ceri',
#  'ceri',
#  'ということでよろしいでしょうか',
#  'ということでよろしいでしょうか',
#  'ノートンwifiプライバシーをoffにして、同じように、xperiaのdocomomail宛に送信。着信します。ブラウザからも見えます。もう一度、ノートンwifiプライバシーをonにして、xperiaのdocomomail宛に送信。mailは何処かに消えます',
#  'offにして送信したmailは、xperiaからもブラウザからも見えます',
#  'xperiaからは、どんな条件でも、macに管理させている、popサーバ、imapサーバへデータが飛んできて、applemailで読めます',
#  'xperia',
#  'でも、ノートンwifiプライバシーを導入するずっと前、10月19日以前のmailは、端末からもブラウザからも見えます',
#  'android上でメールを閲覧するときは',
#  'canada',
#  'orlando',
#  'london',
#  'sorryhulu',
#  'india',
#  'us',
#  'india',
#  'india',
#  'new york',
#  'summerlin',
#  'us',
#  'ceri',
#  'brazil',
#  'burrito',
#  'boston',
#  'boston',
#  'chicago',
#  'netflix',
#  'california',
#  'india',
#  'india',
#  'chicago',
#  'atlanta',
#  'burrito',
#  'helluva',
#  'philadelphia',
#  'london',
#  'india',
#  'us',
#  'charleston',
#  'switzerland',
#  'brazil',
#  'london',
#  'london',
#  'qutar',
#  'kenya',
#  'varsha',
#  'airasia',
#  'bacchusbar',
#  'その場合、無料体験の登録となり、更新をoffにしないと有料会員へ移行します。意図しないご加入で不要であれば、自動更新の設定変更をお願いします',
#  'us',
#  'kennesaw',
#  'louisiana',
#  'manhattan beach',
#  'india',
#  'nashville',
#  'manhattan',
#  'maine',
#  'washington',
#  'washington',
#  'new york',
#  'washington',
#  'india',
#  'hanley',
#  'germany',
#  'us',
#  'togenkyo',
#  'tokyo',
#  'manila',
#  'joyeetacustomer',
#  'america',
#  'virginia',
#  'alaska',
#  'japan',
#  'macon',
#  'us',
#  'the t4 jr',
#  'india',
#  'india',
#  'us',
#  'india',
#  'us',
#  'us',
#  'india',
#  'indonesia',
#  'citi',
#  'indonesia',
#  'australia',
#  'singrauli',
#  'asaly',
#  'india',
#  'texas',
#  '234am',
#  'baltimore city',
#  'chicago',
#  'denver',
#  'denver',
#  'korea',
#  'okayav',
#  'india',
#  'us',
#  'us',
#  'india',
#  'waterfront beach',
#  'huntington beach',
#  'australia',
#  'australia',
#  'amsterdam',
#  'miami',
#  'america',
#  'cleveland',
#  'b’way',
#  'airasia',
#  'dehradun',
#  'hai',
#  '’s',
#  '1205pm',
#  'berlin',
#  'boston',
#  'london',
#  'assistedwo',
#  'atlanta',
#  'dominican republic',
#  'singapore',
#  'qz508',
#  'santa clara',
#  'india',
#  'india',
#  'accesas',
#  'consola',
#  'el mismo',
#  'la membresia',
#  'paddington',
#  'umoh',
#  'india',
#  'maine',
#  '1150pm',
#  'delaware',
#  'new york',
#  'london',
#  'london',
#  'san fran',
#  'london',
#  'paddington',
#  'paddington',
#  'salisbury',
#  'overton',
#  'london',
#  'airasia',
#  'india',
#  'india',
#  'india',
#  'india',
#  'india',
#  'india',
#  'india',
#  'india',
#  'seoul',
#  'la',
#  'paddington',
#  'india',
#  'dhana',
#  'jio',
#  '’s',
#  'us',
#  'ananya',
#  'decisão',
#  'o livro o',
#  'ainda',
#  'ainda',
#  'paris',
#  'new york',
#  'london',
#  'rome',
#  'rome',
#  'rome',
#  'london',
#  'uk',
#  'london',
#  'ewan',
#  'n’t',
#  'airasia',
#  'new orleans',
#  'mumbai',
#  'nottingham',
#  'london',
#  'mumbai',
#  'london',
#  'london',
#  'hersham',
#  'india',
#  'uk',
#  'uk',
#  'uk',
#  'germany',
#  'new york',
#  'bournville',
#  'china',
#  'china',
#  'india',
#  'india',
#  'india',
#  'el segundo',
#  'wt',
#  'north carolina',
#  'la',
#  'atlanta',
#  'atlanta',
#  'jeffindia',
#  'hoooorrrayyy',
#  'la',
#  'madhu',
#  'madhu',
#  'madhu',
#  'orlando',
#  'case00231766',
#  'wolverton',
#  'london',
#  'birmingham',
#  'florida',
#  'georgia',
#  'shanghai',
#  'singapore',
#  'la',
#  'trotzdem mehr',
#  'arbeit',
#  'dallas',
#  'miami',
#  'acton',
#  'acton',
#  'london',
#  'london',
#  'london',
#  'chiswick',
#  'kingslynn',
#  'ewan',
#  'wellington',
#  'ваше',
#  'приложение',
#  'n’t',
#  'motspur park',
#  'aftah',
#  'airasia',
#  'n’t',
#  'n’t',
#  'india',
#  'frankfurt',
#  '’s',
#  'qui',
#  'london',
#  'japan',
#  'austin',
#  'paddington',
#  'ewan',
#  'ewan',
#  'wolverton',
#  'airasia',
#  'charlotte',
#  'uk',
#  'london',
#  'los angeles',
#  'netflix',
#  'ohio',
#  'london',
#  'n’t',
#  'australia',
#  'mumbai',
#  'australia',
#  'manila',
#  'india',
#  'n’t',
#  'long eaton',
#  'london',
#  'india',
#  'us',
#  'uk',
#  'jamaica',
#  'miami',
#  'studio city',
#  'milwaukee',
#  'london',
#  'london',
#  'london',
#  'london',
#  '♀',
#  '♀',
#  '♀',
#  '♀',
#  'texas',
#  'manda',
#  'やはり、amazonの箱は、猫ちゃん達に人気ですね',
#  'orlando',
#  'ksh328300',
#  'london',
#  'airasia',
#  'airasia',
#  'airasia',
#  'kuroda',
#  'balitokyo',
#  'hanoi',
#  'gaya',
#  'uk',
#  'laveen az',
#  'italy',
#  'dublin',
#  'dublin',
#  'kentucky',
#  'n’t',
#  'spain',
#  'spain',
#  'us',
#  'brazil',
#  'brazil',
#  'orlando',
#  'hearthandhand',
#  'clark',
#  'la',
#  'mumbai',
#  'int’l',
#  'us',
#  'london',
#  'london',
#  'london',
#  'london',
#  'charlotte',
#  'gibt',
#  'kharadi pune',
#  '845am',
#  'airasia',
#  'quil',
#  'feltham',
#  'london',
#  'san fran',
#  'london',
#  'madrid',
#  'texas',
#  'london',
#  'london',
#  'san antonio',
#  'new york',
#  'thanksi',
#  'mynorton',
#  'nisha',
#  'scotland',
#  'scotland',
#  'scotland',
#  'britain',
#  'barasa',
#  'india',
#  'london',
#  'india',
#  'ขอบคุณค่ะ',
#  'chicago',
#  'pittsburgh',
#  'watford',
#  'ewan',
#  'sutton',
#  'ewan',
#  'whitehaven',
#  'nisha',
#  'nisha',
#  'london',
#  'georgia',
#  'leg vegas',
#  'newcastle',
#  'wolverton',
#  'scotland',
#  'india',
#  'findest du hier',
#  'sein da',
#  'amar',
#  'ireland',
#  'koramangala',
#  'saudi arabia',
#  'albany',
#  'amsterdam',
#  'bristol',
#  'jordan',
#  'london',
#  'london',
#  'london',
#  'london',
#  'post22',
#  'offers22',
#  'indonesia',
#  'paris',
#  'india',
#  'london',
#  'los angeles',
#  'wolverton',
#  'activewe',
#  'netflix',
#  'jeaneva',
#  'orgulham',
#  'oooo',
#  'london',
#  'jordan',
#  'london',
#  'london',
#  'jordan',
#  'durham',
#  'london',
#  '3rd',
#  'tampcs',
#  '’s',
#  'malaysia',
#  'hartford',
#  'nisha',
#  'nisha',
#  'qj',
#  'angelica',
#  '恐れ入ります。このたびは、ご迷惑をお掛けし誠に申し訳ございませんでした。tn',
#  'india',
#  'paris',
#  'minneapolis',
#  'greenbay',
#  'dallas',
#  'uk',
#  'anya',
#  'london',
#  'birmingham',
#  'london',
#  'birmingham',
#  'us',
#  'us',
#  'bumpa',
#  'colorado',
#  'utah',
#  'california',
#  'georgia',
#  'north carolina',
#  'san juan',
#  'philadelphia',
#  'florida',
#  'mexico',
#  'chicago',
#  'chicago',
#  'north west indiana',
#  'northern ireland',
#  'wiskee',
#  'britain',
#  'scotland',
#  'netflix',
#  'wanda',
#  'us',
#  'canada',
#  'america',
#  'boston',
#  'atlanta',
#  'yt',
#  'ewan',
#  'itah',
#  'nikama',
#  'denver',
#  'illinois',
#  'konto',
#  'london',
#  'london',
#  'london',
#  'n’t',
#  'offers22',
#  'pincode12',
#  'air4',
#  'dallas',
#  'doha',
#  'us',
#  'saint anne',
#  'nashville',
#  'stockholm',
#  'tina',
#  'n’t',
#  'ngong',
#  'karibu',
#  'bana',
#  'kufanya',
#  'london',
#  '⛄',
#  'la',
#  'us',
#  'la',
#  '’s',
#  'n’t',
#  '’s',
#  'india',
#  'n’t',
#  'alaska',
#  'london',
#  'london',
#  'india',
#  'india',
#  'india',
#  'india',
#  'us',
#  'us',
#  'india',
#  'richmond',
#  'london',
#  'konto',
#  'new orleans',
#  'america',
#  'tampa',
#  'dallas',
#  'london',
#  'paddington',
#  'london',
#  'uk',
#  'honiton',
#  'aston',
#  'mediaif',
#  'delhi',
#  'india',
#  'n’t',
#  'canada',
#  'us',
#  'singapore',
#  'minneapolis',
#  'london',
#  'japan',
#  'brazil',
#  'albany',
#  'liverpool',
#  'chippenham',
#  'jordan',
#  'jordan',
#  'london',
#  'kentucky',
#  'china',
#  'london',
#  '神さま',
#  '認識キーは届いてないみたいです',
#  'canada',
#  'mais',
#  'tanto',
#  'canada',
#  'la',
#  'mañana',
#  'lamento el',
#  'mesmo',
#  'kunden',
#  'wann',
#  'n’t',
#  'florida',
#  'atlanta',
#  'debitatmt',
#  'uk',
#  'uk',
#  'uk',
#  'china',
#  'us',
#  'el idioma',
#  'las',
#  'cosas',
#  'quotidien',
#  'helloi',
#  'australia',
#  'malaysia',
#  'london',
#  'chicago',
#  'miami',
#  'america',
#  'london',
#  'scotland',
#  'london',
#  'miami',
#  'las vegas',
#  'america',
#  'varunyana',
#  'airasia',
#  'london',
#  'india',
#  'india',
#  'india',
#  'n’t',
#  'la',
#  'la siguiente',
#  'venda',
#  'portugal',
#  'julianaaa',
#  'tanto',
#  'applewatchseries3',
#  'shld',
#  'turkey',
#  'china',
#  'hong kong',
#  'la',
#  'cont',
#  'dubai',
#  'paddington',
#  'london',
#  'jordan',
#  'london',
#  'delaware',
#  'entregarlo',
#  'trowbridge',
#  'uk',
#  'liverpool',
#  'london',
#  'hpojp8610',
#  'uk',
#  'nobrand',
#  'originais',
#  'india',
#  'nyc david',
#  'aa2468',
#  'cuba',
#  'cuba',
#  'cuba',
#  'miami',
#  'cuba',
#  'miami',
#  'florida',
#  'jordan',
#  'london',
#  'scotland',
#  'britain',
#  'scotland',
#  'france',
#  'optionea',
#  'london',
#  'california',
#  'keiran',
#  'miami',
#  'hong kong',
#  'los dispositivos',
#  'el servicio en el',
#  'rian',
#  'west africa',
#  'miami',
#  'kava',
#  'kombucha',
#  'kava',
#  'burrito',
#  ...]

# %% [markdown]
# From the above 2 tasks we can analyze that the dataset us about tweets regarding customer service. Customers ask for help mostly with their accounts, money and refunds, games such as xbox, various locations in the world but majorly US states and Europe.
